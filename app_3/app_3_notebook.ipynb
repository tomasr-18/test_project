# %%
import requests
from google.cloud import bigquery
from datetime import datetime, timedelta
import json

# %%
def get_news(company_list, api_key: str, sortBy='relevance', language='en', from_date=None, to_date=datetime.datetime.now().strftime('%Y-%m-%d')) -> pd.DataFrame:
    """
    This function returns the news articles for a given company from the News API.
    """
    df_list = []
    for company in company_list:

        api_search = f'https://newsapi.org/v2/everything?q={company}&from={
            from_date}&to={to_date}&sortBy={sortBy}&language={language}&apiKey={api_key}'

        try:
            response = requests.get(api_search).json()
            if response.get('status') == 'ok':

                # Extract specific information
                articles = response.get('articles', [])
                extracted_info = []
                for article in articles:
                    source_name = article.get('source', {}).get('name')
                    title = article.get('title')
                    description = article.get('description')
                    published_at = article.get('publishedAt')
                    extracted_info.append({
                        'company': company,
                        'source_name': source_name,
                        'title': title,
                        'description': description,
                        'published_at': published_at
                    })

            else:
                print('Error in the API response')
                extracted_info = []

        except requests.exceptions.RequestException as e:
            print(e)
            print(response.status_code)
        df = pd.DataFrame(extracted_info)
        df_list.append(df)

    df = pd.concat(df_list)

    return df

# %%
def get_data(company: str, api_key: str, from_date=(datetime.now() - timedelta(days=1)).strftime('%Y-%m-%d'), to_date=datetime.now().strftime('%Y-%m-%d'), sort_by='relevance', language='en'):

    url = f'https://newsapi.org/v2/everything?q={company}&from={from_date}&to={
        to_date}&sortBy={sort_by}&language={language}&apiKey={api_key}'
    response = requests.get(url=url)
    if response.status_code == 200:
        return response.json()
    else:
        print('fel!')

# %%
data_raw = get_data(
    company='Apple', api_key='d3a5fafb5fc4415fb7f4f33a2a399250', from_date='2024-08-20')

# %%
def write(data, company: str, table='table_1', project_id='tomastestproject-433206', dataset='testdb_1') -> None:

    # Initiera BigQuery-klienten
    client = bigquery.Client.from_service_account_json(
        '/Users/tomasrydenstam/Downloads/tomastestproject-433206-adc5bc090976.json')

    # Definiera din dataset och tabell
    table_id = f"{project_id}.{dataset}.{table}"
    print(table_id)

    rows_to_insert = []

    for row in data['articles']:
        row['source'] = row['source']['name']
        row['company'] = company
        row['fetch_date'] = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        rows_to_insert.append(row)
    print(rows_to_insert)

    errors = client.insert_rows_json(table_id, rows_to_insert)
    print(errors)

# %%
data_raw
# Out:
# {'status': 'ok',
#  'totalResults': 1831,
#  'articles': [{'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Lawrence Bonk',
#    'title': 'Apple event rumor roundup: What to expect at the iPhone 16 keynote',
#    'description': 'The biggest day of the tech world’s fall calendar is nearly here: Apple’s iPhone 16 event will take place sometime in September. The company typically does it on a Tuesday during the first half of the month, so September 10 is a safe bet. No matter when it ha…',
#    'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_7de77318-ab44-441e-a0d7-b47c8388fcdd',
#    'urlToImage': None,
#    'publishedAt': '2024-08-20T19:23:47Z',
#    'content': "If you click 'Accept all', we and our partners, including 237 who are part of the IAB Transparency &amp; Consent Framework, will also store and/or access information on a device (in other words, use … [+678 chars]"},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Antonio G. Di Benedetto',
#    'title': 'Nomad’s latest Base One Max 3-in-1 charger is more than $50 off',
#    'description': 'The second-gen Nomad Base One Max can simultaneously charge a MagSafe-ready iPhone, AirPods, and an Apple Watch — and it’s on sale this week for just $119.',
#    'url': 'https://www.theverge.com/2024/8/20/24224722/nomad-base-one-max-3-in-1-magsafe-magnetic-charger-deal-sale',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/H2oyewvIg0Q1Dbkp77vAXpoPo7w=/0x0:1758x1258/1200x628/filters:focal(879x629:880x630)/cdn.vox-cdn.com/uploads/chorus_asset/file/25251597/Nomad_Base_One_Max_3_in_1_MagSafe_Charger.jpg',
#    'publishedAt': '2024-08-20T21:14:26Z',
#    'content': 'Nomads latest Base One Max 3-in-1 charger is more than $50 off\r\nNomads latest Base One Max 3-in-1 charger is more than $50 off\r\n / For $119, you get a very fancy MagSafe charger for your iPhone, Appl… [+1750 chars]'},
#   {'source': {'id': None, 'name': '[Removed]'},
#    'author': None,
#    'title': '[Removed]',
#    'description': '[Removed]',
#    'url': 'https://removed.com',
#    'urlToImage': None,
#    'publishedAt': '1970-01-01T00:00:00Z',
#    'content': '[Removed]'},
#   {'source': {'id': None, 'name': '[Removed]'},
#    'author': None,
#    'title': '[Removed]',
#    'description': '[Removed]',
#    'url': 'https://removed.com',
#    'urlToImage': None,
#    'publishedAt': '1970-01-01T00:00:00Z',
#    'content': '[Removed]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Tim Hardwick',
#    'title': 'Apple Music Offering Free Three-Month Trial for a Limited Time',
#    'description': "Apple is offering an extended three-month free Apple Music trial for new users over the summer, provided they haven't been a subscriber to the streaming service before.\n\n\n\n\n\n\u200cApple Music\u200c typically offers a one-month free trial for new subscribers since it wa…",
#    'url': 'https://www.macrumors.com/2024/08/20/apple-music-free-three-month-trial/',
#    'urlToImage': 'https://images.macrumors.com/t/cBpeJ95wekMRm8-YbPPJQhJrDsY=/1920x/article-new/2024/08/apple-music.jpg',
#    'publishedAt': '2024-08-20T12:56:29Z',
#    'content': "Apple is offering an extended three-month free Apple Music trial for new users over the summer, provided they haven't been a subscriber to the streaming service before.\r\nApple Music typically offers … [+892 chars]"},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Tim Hardwick',
#    'title': 'macOS Sequoia Has New FaceTime Backgrounds Showcasing Apple Park',
#    'description': "Apple in the second beta of macOS Sequoia 15.1 has added a set of new backgrounds for FaceTime calls that showcase features of Apple Park.\n\n\n\n\n\nThere are nine backgrounds in all, featuring iconic locations around the company's circular headquarters in Cuperti…",
#    'url': 'https://www.macrumors.com/2024/08/20/macos-sequoia-new-facetime-backgrounds/',
#    'urlToImage': 'https://images.macrumors.com/t/AH7LgCRE82dai24GwTtpnidUEIg=/1920x/article-new/2024/08/macos-sequoia-facetime-backgrounds.jpg',
#    'publishedAt': '2024-08-20T10:30:10Z',
#    'content': 'Apple in the second beta of macOS Sequoia 15.1 has added a set of new backgrounds for FaceTime calls that showcase features of Apple Park.\r\nThere are nine backgrounds in all, featuring iconic locatio… [+1353 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Juli Clover',
#    'title': 'Apple Releases New Firmware for Beats Studio Pro',
#    'description': 'Apple today released new firmware for the Beats Studio Pro over-ear headphones. The Beats Studio Pro can be updated to firmware version 10M7529, up from the prior 2B68 firmware that was installed on the headphones at launch. Note that the 10M7529 firmware num…',
#    'url': 'https://www.macrumors.com/2024/08/20/apple-releases-new-firmware-for-beats-studio-pro/',
#    'urlToImage': 'https://images.macrumors.com/t/Culu7KPCVbwscCzTNrTy9UXgBNg=/1600x/article-new/2023/07/beats-studio-pro-iphone.jpg',
#    'publishedAt': '2024-08-20T22:30:39Z',
#    'content': 'Apple today released new firmware for the Beats Studio Pro over-ear headphones. The Beats Studio Pro can be updated to firmware version 10M7529, up from the prior 2B68 firmware that was installed on … [+1358 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Juli Clover',
#    'title': 'Apple Seeds Seventh Beta of macOS Sequoia to Developers',
#    'description': 'Apple today seeded the seventh beta of upcoming an upcoming macOS 15 Sequoia update to developers for testing purposes, with the software coming a week after the release of the sixth beta.\n\n\n\n\n\nRegistered developers can opt-in to the macOS Sequoia beta throug…',
#    'url': 'https://www.macrumors.com/2024/08/20/apple-seeds-macos-sequoia-beta-7/',
#    'urlToImage': 'https://images.macrumors.com/t/zZbcqD0-kgQ9SCr6AnSkKJIiULE=/2500x/article-new/2024/06/macOS-Sequoia-Feature.jpg',
#    'publishedAt': '2024-08-20T17:08:11Z',
#    'content': 'Apple today seeded the seventh beta of upcoming an upcoming macOS 15 Sequoia update to developers for testing purposes, with the software coming a week after the release of the sixth beta.\r\nRegistere… [+1391 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Tim Hardwick',
#    'title': 'Kuo: Folding All-Screen MacBook Delayed Until Late 2027 At the Earliest',
#    'description': "Apple's rumored foldable MacBook won't arrive until the end of 2027 or 2028 at the earliest because of technical challenges, according to the latest prediction by Apple analyst Ming-Chi Kuo.\n\n\n\nConcept by Astropad\n\nPrevious reports from display industry analy…",
#    'url': 'https://www.macrumors.com/2024/08/22/kuo-foldable-macbook-delayed-2027/',
#    'urlToImage': 'https://images.macrumors.com/t/zKktJKfU2gMwxRwH3vDHqQb2HYs=/1600x/article-new/2024/05/Foldable-Screen-MacBook-Concept-Astropad.jpg',
#    'publishedAt': '2024-08-22T10:50:25Z',
#    'content': "Apple's rumored foldable MacBook won't arrive until the end of 2027 or 2028 at the earliest because of technical challenges, according to the latest prediction by Apple analyst Ming-Chi Kuo.\r\nPreviou… [+2521 chars]"},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Juli Clover',
#    'title': 'Nomad Launches Stand One Max Qi2 Charging Hub for iPhone, Apple Watch and AirPods',
#    'description': 'Nomad today introduced its latest multi-device charger, debuting a new version of the Stand One Max with Qi2 support. Rather than continuing to use MagSafe, Nomad is transitioning to Qi2, the latest Qi charging standard that is able to charge iPhones at \u200cMagS…',
#    'url': 'https://www.macrumors.com/2024/08/21/nomad-qi2-stand-one-max/',
#    'urlToImage': 'https://images.macrumors.com/t/MldafrVnP26lcgWrqzCIxDrqzQE=/2000x/article-new/2024/08/nomad-stand-one-max-2.jpg',
#    'publishedAt': '2024-08-21T16:00:00Z',
#    'content': 'Nomad today introduced its latest multi-device charger, debuting a new version of the Stand One Max with Qi2 support. Rather than continuing to use MagSafe, Nomad is transitioning to Qi2, the latest … [+2505 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Emma Roth',
#    'title': 'Authors sue Anthropic for training AI using pirated books',
#    'description': 'The proposed class action suit claims Anthropic used pirated books sourced from a dataset called The Pile to train its family of Claude AI models.',
#    'url': 'https://www.theverge.com/2024/8/20/24224450/anthropic-copyright-lawsuit-pirated-books-ai',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/vNMfM5bpGgs8ixA4ksEjBydTG-4=/0x0:2040x1360/1200x628/filters:focal(1020x680:1021x681)/cdn.vox-cdn.com/uploads/chorus_asset/file/25469772/STK269_ANTHROPIC_A.jpg',
#    'publishedAt': '2024-08-20T16:54:37Z',
#    'content': 'Authors sue Anthropic for training AI using pirated books\r\nAuthors sue Anthropic for training AI using pirated books\r\n / The authors accuse Anthropic of copyright infringement for training its AI mod… [+2357 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Tim Hardwick',
#    'title': "New iPhone 16 Thermal Design High on Buyers' Wishlist, Survey Suggests",
#    'description': 'A recent survey conducted by SellCell suggests that a significant majority of iPhone users are planning to upgrade to the upcoming iPhone 16 series, with many expressing a preference for a better thermal design to prevent overheating issues. \n\n\n\n\n\nThe survey,…',
#    'url': 'https://www.macrumors.com/2024/08/20/iphone-16-pre-launch-survey-overheating/',
#    'urlToImage': 'https://images.macrumors.com/t/dQzfQzCqjlEJdrgq3QVPbLFzfeM=/3532x/article-new/2023/09/iPhone-16-Side-Feature.jpg',
#    'publishedAt': '2024-08-20T11:49:42Z',
#    'content': 'A recent survey conducted by SellCell suggests that a significant majority of iPhone users are planning to upgrade to the upcoming iPhone 16 series, with many expressing a preference for a better the… [+2323 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Tim Hardwick',
#    'title': 'UK Antitrust Watchdog Closes Apple App Store Investigation, Case to Be Reconsidered Under New Digital Rules Regime',
#    'description': "The UK's Competition and Market Authority (CMA) today announced it had closed an investigation into Apple's App Store policies, as it expects to consider the concerns under a new digital markets competition regime which is expected to come into force later th…",
#    'url': 'https://www.macrumors.com/2024/08/21/uk-antitrust-watchdog-closes-probe-app-store/',
#    'urlToImage': 'https://images.macrumors.com/t/oNd60UHBH70Ze0PtFNPGSCa0cKQ=/1794x/article-new/2021/06/app-store-blue-banner-uk-fixed.jpg',
#    'publishedAt': '2024-08-21T11:37:01Z',
#    'content': "The UK's Competition and Market Authority (CMA) today announced it had closed an investigation into Apple's App Store policies, as it expects to consider the concerns under a new digital markets comp… [+2493 chars]"},
#   {'source': {'id': None, 'name': '[Removed]'},
#    'author': None,
#    'title': '[Removed]',
#    'description': '[Removed]',
#    'url': 'https://removed.com',
#    'urlToImage': None,
#    'publishedAt': '1970-01-01T00:00:00Z',
#    'content': '[Removed]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Mitchel Broussard',
#    'title': "Amazon's New Accessory Sale Includes Deals on AirTag, Eufy SmartTrack, and Jackery Power Stations",
#    'description': "Today we're tracking a big collection of discounts on Bluetooth trackers and portable power stations, including Apple's own AirTag, Anker's more affordable brand of Eufy SmartTrack accessories, and power stations from Jackery. All of these deals can be found …",
#    'url': 'https://www.macrumors.com/2024/08/21/amazon-airtag-eufy-jackery/',
#    'urlToImage': 'https://images.macrumors.com/t/CYPlhzPvRwbX-M884hlokABZGto=/2250x/article-new/2024/08/jackery-blue.jpg',
#    'publishedAt': '2024-08-21T15:17:16Z',
#    'content': "Today we're tracking a big collection of discounts on Bluetooth trackers and portable power stations, including Apple's own AirTag, Anker's more affordable brand of Eufy SmartTrack accessories, and p… [+1926 chars]"},
#   {'source': {'id': None, 'name': 'PCMag.com'},
#    'author': 'PC Mag',
#    'title': 'Amazon Deals of The Day: A Rare 40% Discount on an Apple iPad (9th Gen)',
#    'description': "You can also score the latest Amazon Echo Spot (2024) for 30% less (the lowest price we've seen all year on this model) and a 32-inch Amazon Fire TV 2-Series...",
#    'url': 'https://www.pcmag.com/deals/amazon-deals-of-the-day-apple-ipad-9th-gen-august-21',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/r8aHfq_XVV3Ubk3ik3AYxA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://media.zenfs.com/en/pc_mag_263/ad087856c4fa7cd9af3361187334acef',
#    'publishedAt': '2024-08-21T15:00:09Z',
#    'content': 'The powerhouse iPad (9th Gen) is now 40% off, which for any Apple product, is an amazing discount. This model features the A13 Bionic chip, a stunning 10.2-inch True Tone display, and a 12MP ultra-wi… [+2716 chars]'},
#   {'source': {'id': None, 'name': 'Android Central'},
#    'author': 'jerry.hildenbrand@futurenet.com (Jerry Hildenbrand)',
#    'title': 'Using plastic packaging is dumb. Google just stopped doing it.',
#    'description': "Diamonds are forever. So is plastic. Let's stop using it as a packing material.",
#    'url': 'https://www.androidcentral.com/phones/google-just-stopped-using-plastic-packaging',
#    'urlToImage': 'https://cdn.mos.cms.futurecdn.net/Hv8oQ6qzM8gwVwe3J7sUwW-1200-80.jpg',
#    'publishedAt': '2024-08-20T18:26:52Z',
#    'content': "Google quietly announced something that most people aren't going to pay any attention to, even though we all should; it's one of the most important things the company has done.\r\nIt has stopped using … [+3083 chars]"},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Juli Clover',
#    'title': 'OnePlus Buds Pro 3 vs. AirPods Pro 2',
#    'description': "Chinese company OnePlus is debuting new earbuds today, with a feature set that pits them against the AirPods Pro. The OnePlus Buds Pro 3 look and sound a lot like Apple's AirPods, and while they lack some of the Apple-esque magic integration, they're more aff…",
#    'url': 'https://www.macrumors.com/2024/08/20/oneplus-buds-pro-3-vs-airpods-pro-2/',
#    'urlToImage': 'https://images.macrumors.com/t/LruKR3Eo15neLHaTwhJR3MCkp-Q=/2428x/article-new/2024/08/OnePlus-Buds-Pro-3-Thumb-2.jpg',
#    'publishedAt': '2024-08-20T17:58:01Z',
#    'content': "Chinese company OnePlus is debuting new earbuds today, with a feature set that pits them against the AirPods Pro. The OnePlus Buds Pro 3 look and sound a lot like Apple's AirPods, and while they lack… [+2375 chars]"},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Juli Clover',
#    'title': 'iPhone 15 Pro Max: One Year Review',
#    'description': "It's been almost a year since the iPhone 15 models were released, so MacRumors videographer Dan Barbera decided to do a one-year check-in review on the iPhone 15 Pro Max to see how it's performed over the last 12 months.\n\n\n\n\r\nSubscribe to the MacRumors YouTub…",
#    'url': 'https://www.macrumors.com/2024/08/21/iphone-15-pro-max-one-year-review/',
#    'urlToImage': 'https://images.macrumors.com/t/N8cDn-8zPTMw5asPHnHyVE4Lfv0=/2500x/article-new/2024/08/iPhone-15-Pro-Max-1-Year-Later-Thumb-3.jpg',
#    'publishedAt': '2024-08-21T17:53:30Z',
#    'content': "It's been almost a year since the iPhone 15 models were released, so MacRumors videographer Dan Barbera decided to do a one-year check-in review on the iPhone 15 Pro Max to see how it's performed ove… [+2251 chars]"},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Ryan Christoffel',
#    'title': 'Apple Watch Ultra 3 may be a harder sell than ever before',
#    'description': 'In a few short weeks, Apple will hold its iPhone 16 event. Though not the star of the show, new Apple Watch models will debut alongside the iPhone. An Apple Watch Series 10 and Apple Watch Ultra 3 are coming. But there’s a problem: the Series 10 is set to gai…',
#    'url': 'https://9to5mac.com/2024/08/20/apple-watch-ultra-3-may-be-a-harder-sell-than-ever-before/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2022/09/Apple-Watch-Ultra-Release.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-20T15:26:30Z',
#    'content': 'In a few short weeks, Apple will hold its iPhone 16 event. Though not the star of the show, new Apple Watch models will debut alongside the iPhone. An Apple Watch Series 10 and Apple Watch Ultra 3 ar… [+2885 chars]'},
#   {'source': {'id': None, 'name': '[Removed]'},
#    'author': None,
#    'title': '[Removed]',
#    'description': '[Removed]',
#    'url': 'https://removed.com',
#    'urlToImage': None,
#    'publishedAt': '1970-01-01T00:00:00Z',
#    'content': '[Removed]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Filipe Espósito',
#    'title': 'Could Apple hold the iPhone 16 event a week earlier than expected?',
#    'description': 'It’s no secret that Apple usually announces new in September with a special event at Apple Park. My colleague Chance Miller had already speculated here on 9to5Mac about a possible date for the iPhone 16 event this year. However, what if Apple held this year’s…',
#    'url': 'https://9to5mac.com/2024/08/20/apple-iphone-16-september-event/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/08/tim-cook-iphone-apple-event.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-20T19:45:35Z',
#    'content': 'It’s no secret that Apple usually announces new iPhones in September with a special event at Apple Park. My colleague Chance Miller had already speculated here on 9to5Mac about a possible date for th… [+2505 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Kyle Barr',
#    'title': 'The New Samsung Odyssey Could Fix the Most Annoying Thing About 3D Gaming',
#    'description': "Samsung promises there’s a 27-inch and 37-inch Odyssey 3D monitor coming later this year, though we don't know how expensive it will be.",
#    'url': 'https://gizmodo.com/the-new-samsung-odyssey-could-fix-the-most-annoying-thing-about-3d-gaming-2000489287',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2024/08/Samsung-TVs-and-Displays-Odyssey-3D-Gamescom-2024_main1.jpeg',
#    'publishedAt': '2024-08-21T14:25:22Z',
#    'content': 'If youre a Samsung Odyssey monitor fan, you already have plenty of expensive options for 4K gaming with OLEDs like the G6 and G8. Samsung now says that 2D screens is old hat. The company is soon goin… [+2912 chars]'},
#   {'source': {'id': None, 'name': 'AppleInsider'},
#    'author': 'news@appleinsider.com (Christine McKee)',
#    'title': 'Amazon clears out Apple Watch inventory, grab the Series 9 for $299 & Ultra 2 for $699',
#    'description': 'Amazon is slashing Apple Watch prices ahead of the September Apple event, resulting in the return of Prime Day pricing on multiple Series 9 and Ultra 2 styles.Amazon is blowing out Apple Watch inventory.As September inches closer, the Apple Watch deals are he…',
#    'url': 'https://appleinsider.com/articles/24/08/20/amazon-clears-out-apple-watch-inventory-grab-the-series-9-for-299-ultra-2-for-699',
#    'urlToImage': 'https://photos5.appleinsider.com/gallery/60747-125055-apple-watch-sale-2024-xl.jpg',
#    'publishedAt': '2024-08-20T14:06:55Z',
#    'content': 'Amazon is blowing out Apple Watch inventory.\r\nAmazon is slashing Apple Watch prices ahead of the September Apple event, resulting in the return of Prime Day pricing on multiple Series 9 and Ultra 2 s… [+508 chars]'},
#   {'source': {'id': None, 'name': 'AppleInsider'},
#    'author': 'news@appleinsider.com (Mike Wuerthele and Wes Hilliard)',
#    'title': 'Apple Vision Pro review: six month stasis',
#    'description': 'After six months with Apple Vision Pro, things feel stuck. A glacial rollout of immersive content, a lack of native apps, and no word of Apple Intelligence make the $3,500 product harder to swallow.Apple Vision Pro review: stuck in placeApple Vision Pro is fr…',
#    'url': 'https://appleinsider.com/articles/24/08/20/apple-vision-pro-review-six-month-stasis',
#    'urlToImage': 'https://photos5.appleinsider.com/gallery/60333-124789-VP29-xl.jpg',
#    'publishedAt': '2024-08-20T12:09:49Z',
#    'content': 'Apple Vision Pro review: stuck in place\r\nAfter six months with Apple Vision Pro, things feel stuck. A glacial rollout of immersive content, a lack of native apps, and no word of Apple Intelligence ma… [+23497 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Chance Miller',
#    'title': 'App Store VP departing Apple amid broader restructuring',
#    'description': 'Apple’s App Store vice president is leaving the company in October, according to a new report from Bloomberg. \n\n\n\nThe structure of the App Store team is also being split into two teams, a change implemented by Phil Schiller in response to the ever-changing Ap…',
#    'url': 'https://9to5mac.com/2024/08/21/app-store-vp-departing-apple-amid-broader-restructuring/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/06/track-manage-apple-app-store-subscriptions.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-21T19:54:59Z',
#    'content': 'Apple’s App Store vice president is leaving the company in October, according to a new report from Bloomberg. \r\nThe structure of the App Store team is also being split into two teams, a change implem… [+2081 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Zac Hall',
#    'title': 'Double tappin’ watchOS 11 on Apple Watch Series 9',
#    'description': 'Apple Watch and Ultra 2 introduce the double tap gesture, and I’ve found that the upcoming watchOS 11 update makes the hands-free input method more useful.\n\n\n\nDouble tap lets you interact with the Apple Watch by doing a two-tap gesture with your thumb and fin…',
#    'url': 'https://9to5mac.com/2024/08/20/double-tap-smart-stack-watchos-11-apple-watch/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/06/Screenshot-2024-06-10-at-1.43.20-PM.webp?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-20T18:07:41Z',
#    'content': 'Apple Watch Series 9 and Ultra 2 introduce the double tap gesture, and I’ve found that the upcoming watchOS 11 update makes the hands-free input method more useful.\r\nDouble tap lets you interact with… [+5131 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Chance Miller',
#    'title': 'macOS Sequoia includes new Apple Park backgrounds for video conferencing apps',
#    'description': 'As we approach the public release of macOS Sequoia this fall, Apple continues to add new features. In the latest macOS Sequoia betas, there are nine new built-in backgrounds for video conferencing apps that showcase various different parts of Apple Park.\n\n\n\n …',
#    'url': 'https://9to5mac.com/2024/08/20/macos-sequoia-apple-park-backgrounds/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2023/10/apple-park-dusk.jpeg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-20T16:25:21Z',
#    'content': 'As we approach the public release of macOS Sequoia this fall, Apple continues to add new features. In the latest macOS Sequoia betas, there are nine new built-in backgrounds for video conferencing ap… [+1229 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Michael Potuck',
#    'title': 'Nomad launches Stand One Max with Qi2, Apple Watch fast charger, metal and glass design',
#    'description': 'Upgrading its premium charger lineup for Apple devices, Nomad has released the 3rd gen Stand One Max. Built with a metal and glass design, features include Qi2 support with 15W wireless charging, Apple Watch fast charging, and a charger for AirPods. Read on f…',
#    'url': 'https://9to5mac.com/2024/08/21/nomad-launches-stand-one-max-with-qi2-iphone-apple-watch-airpods/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/08/nomad-stand-one-max-3rd-gen.jpeg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-21T16:00:00Z',
#    'content': 'Upgrading its premium charger lineup for Apple devices, Nomad has released the 3rd gen Stand One Max. Built with a metal and glass design, features include Qi2 support with 15W wireless charging, App… [+2812 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Juli Clover',
#    'title': "PSA: There's New Character Bug That Can Cause iPhones to Crash",
#    'description': 'There is a new character bug that can result in a respring on the iPhone or iPad, reports TechCrunch. Typing "":: in the search field after swiping over to the App Library will cause the Springboard to reset, dropping you back at the \u200ciPhone\u200c\'s Lock Screen. A…',
#    'url': 'https://www.macrumors.com/2024/08/21/iphone-character-bug-respring/',
#    'urlToImage': 'https://images.macrumors.com/t/FWFeAmxnHKf7vkk_MCBh9TcNMVg=/1600x/article-new/2023/05/bug-security-vulnerability-issue-fix-larry.jpg',
#    'publishedAt': '2024-08-21T19:25:41Z',
#    'content': 'There is a new character bug that can result in a respring on the iPhone or iPad, reports TechCrunch. Typing "":: in the search field after swiping over to the App Library will cause the Springboard … [+1209 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Ryan Christoffel',
#    'title': 'There’s no beta for Genmoji or AI image generation, and Pixel 9 headlines explain why',
#    'description': 'Today reviews dropped for Google’s AI-packed Pixel 9 phones. Why mention that on an Apple site? Because the headlines Google’s getting help explain why Apple Intelligence’s image generation features are still MIA from the iOS 18.1 beta. In fact, the more head…',
#    'url': 'https://9to5mac.com/2024/08/21/theres-no-beta-for-genmoji-or-ai-image-generation-and-pixel-9-headlines-explain-why/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/08/genmoji-generative-ai.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-21T20:19:00Z',
#    'content': 'Today reviews dropped for Googles AI-packed Pixel 9 phones. Why mention that on an Apple site? Because the headlines Googles getting help explain why Apple Intelligences image generation features are… [+3115 chars]'},
#   {'source': {'id': None, 'name': 'AppleInsider'},
#    'author': 'news@appleinsider.com (William Gallagher)',
#    'title': 'Arm-mounted haptics could make future iPhone notifications more discreet',
#    'description': "Even silent alerts can be audible if an Apple Watch haptic engine is too powerful, but Apple has plans to make notifications entirely private.Detail from the patent. Notice the armband and possibly an Apple Bracelet tooYou're at a meeting and it's time for yo…",
#    'url': 'https://appleinsider.com/articles/24/08/20/arm-mounted-haptics-could-make-future-iphone-notifications-more-discreet',
#    'urlToImage': 'https://photos5.appleinsider.com/gallery/60749-125059-000-lede-haptic-d2-xl.jpg',
#    'publishedAt': '2024-08-20T14:52:59Z',
#    'content': 'Detail from the patent. Notice the armband and possibly an Apple Bracelet too\r\nEven silent alerts can be audible if an Apple Watch haptic engine is too powerful, but Apple has plans to make notificat… [+2972 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Justin Kahn',
#    'title': 'Deals: Apple Watch Series 9 $100 off, M2 MacBook Air $699, Nomad Base One Max MagSafe charger 30% off, and more',
#    'description': 'Your mid-week collection of deals on Apple gear and accessories for them all is now up for grabs down below. The return of $100 price drops across a number of Apple Watch Series 9 configurations are at the ready, but we also have new lows on elevated M3 iMac …',
#    'url': 'https://9to5mac.com/2024/08/21/deals-apple-watch-macbook-air-nomad/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/08/Apple-deals-iMac-Apple-Watch-more.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-21T15:46:36Z',
#    'content': 'Your mid-week collection of deals on Apple gear and accessories for them all is now up for grabs down below. The return of $100 price drops across a number of Apple Watch Series 9 configurations are … [+9370 chars]'},
#   {'source': {'id': None, 'name': 'Macworld'},
#    'author': 'Roman Loyola',
#    'title': 'The M4 Mac mini will be like no other Mac you’ve ever seen',
#    'description': 'Macworld\n\n\n\r\n\n\n\n\n2024 may end up being a big year for Apple’s smallest Mac. While other Macs are rumored to get iterative spec bumps, the Mac mini will reportedly undergo drastic changes–changes that may shift the perception of the device. When all is said an…',
#    'url': 'https://www.macworld.com/article/2427858/the-m4-mac-mini-will-be-like-no-other-mac-youve-ever-seen.html',
#    'urlToImage': 'https://www.macworld.com/wp-content/uploads/2024/08/mac-mini-apple-tv-graphic-1.jpg?quality=50&strip=all&w=1024',
#    'publishedAt': '2024-08-22T10:30:00Z',
#    'content': "Skip to contentType your search and hit enter\r\nWhen you purchase through links in our articles, we may earn a small commission. This doesn't affect our editorial independence\r\n.\r\n2024 may end up bein… [+9830 chars]"},
#   {'source': {'id': None, 'name': 'AppleInsider'},
#    'author': 'news@appleinsider.com (Andrew Orr)',
#    'title': "iCloud storage leads the pack in Apple's services ecosystem",
#    'description': "With hardware sales slowing, Apple shifted to expanding its digital services offerings to generate billions each quarter. One service stands out as the clear leader.iCloud storage leads the pack in Apple's services ecosystemApple has been aggressively expandi…",
#    'url': 'https://appleinsider.com/articles/24/08/21/icloud-storage-leads-the-pack-in-apples-services-ecosystem',
#    'urlToImage': 'https://photos5.appleinsider.com/gallery/60769-125085-icloud-icon-xl.jpg',
#    'publishedAt': '2024-08-21T14:29:55Z',
#    'content': "iCloud storage leads the pack in Apple's services ecosystem\r\nLast updated 17 seconds ago\r\nWith hardware sales slowing, Apple shifted to expanding its digital services offerings to generate billions e… [+2582 chars]"},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Juli Clover',
#    'title': 'iPhone Photography Awards Highlight Best Images of 2024',
#    'description': "Every year, the iPhone Photography Awards (IPPA) selects the best photographs captured with an \u200ciPhone\u200c, and the 2024 award winners were announced today. Many of this year's winning images were taken with Apple's most recent iPhone 15 models.\n\n\n\n\n\nThe grand p…",
#    'url': 'https://www.macrumors.com/2024/08/20/iphone-photography-awards-2024/',
#    'urlToImage': 'https://images.macrumors.com/t/fE5bcTOP5ymqO6mizljgEB7pvy4=/2500x/article-new/2023/09/iPhone-15-Blue-Three-Quarters-Perspective-Camera-Closeup-Feature.jpg',
#    'publishedAt': '2024-08-20T22:42:00Z',
#    'content': "Every year, the iPhone Photography Awards (IPPA) selects the best photographs captured with an \u200ciPhone\u200c, and the 2024 award winners were announced today. Many of this year's winning images were taken… [+932 chars]"},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Reuters Videos',
#    'title': "We are 'cautious bulls' on market -portfolio manager",
#    'description': 'STORY: "We know that the market is not cheap. If we look at forward earnings, it\'s a little bit turn or two higher than historical averages, not aggressively...',
#    'url': 'https://finance.yahoo.com/video/cautious-bulls-market-portfolio-manager-195407752.html',
#    'urlToImage': 'https://media.zenfs.com/en/video.reutersnews.com/1a66d1b4f70e1cd00ab60d1bed1cd09c',
#    'publishedAt': '2024-08-21T19:54:07Z',
#    'content': 'STORY: "We know that the market is not cheap. If we look at forward earnings, it\'s a little bit turn or two higher than historical averages, not aggressively so. So not in a bubble scenario, but it\'s… [+175 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Matthew S. Smith',
#    'title': "The founder of a software-development company says there's a 'huge demand' for training and education applications — extended reality can help",
#    'description': 'Treeview uses augmented- and virtual-reality tools with AI to develop software and metaverse projects. Its clients include Microsoft and Medtronic.',
#    'url': 'https://www.businessinsider.com/treeview-extended-reality-artificial-intelligence-software-development-metaverse-2024-8',
#    'urlToImage': 'https://i.insider.com/66c4e6b4b4912df3ae1d0fd5?width=1200&format=jpeg',
#    'publishedAt': '2024-08-21T16:55:20Z',
#    'content': 'Horacio Torrendell; Getty Images; Alyssa Powell/BI\r\n<ul><li>Treeview is a developer of extended-reality software that serves clients such as Microsoft.</li><li>Its founder spoke with BI about the com… [+8155 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Michael Potuck',
#    'title': 'Here’s Apple’s most popular service in 2024',
#    'description': 'As iPhone sales slow down, Apple’s services become more important to grow the company’s revenue. Looking into which of the company’s offerings are most popular, CIRP has published a report revealing what services Apple customers use.\n\n\n\n more…',
#    'url': 'https://9to5mac.com/2024/08/21/apples-most-popular-service-in-2024/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2021/04/apple-services.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-21T18:04:33Z',
#    'content': 'As iPhone sales slow down, Apple’s services become more important to grow the company’s revenue. Looking into which of the company’s offerings are most popular, CIRP has published a report revealing … [+1203 chars]'},
#   {'source': {'id': None, 'name': 'AppleInsider'},
#    'author': 'news@appleinsider.com (Andrew Orr)',
#    'title': 'Apple leads global mobile market, outpacing competitors in advertising',
#    'description': "Apple continues to dominate the global mobile device market, now securing the top position in programmatic advertising share.Apple leads global mobile market, outpacing competitors in advertisingApple's dominance in the global mobile device market continues, …",
#    'url': 'https://appleinsider.com/articles/24/08/21/apple-leads-global-mobile-market-outpacing-competitors-in-advertising',
#    'urlToImage': 'https://photos5.appleinsider.com/gallery/60774-125099-apple-park-xl.jpg',
#    'publishedAt': '2024-08-21T21:19:38Z',
#    'content': 'Apple leads global mobile market, outpacing competitors in advertising\r\nApple continues to dominate the global mobile device market, now securing the top position in programmatic advertising share.\r\n… [+2325 chars]'},
#   {'source': {'id': None, 'name': 'AppleInsider'},
#    'author': 'news@appleinsider.com (William Gallagher)',
#    'title': 'Apple spotlights how its technology is helping 4-H youth development',
#    'description': 'As part of its Community Education Initiative, Apple says that its work with 4-H programs has reached over 90,000 young people from communities across the US that are traditionally underrepresented in technology.Mark Light has introduced thousands of young pe…',
#    'url': 'https://appleinsider.com/articles/24/08/21/apple-spotlights-how-its-technology-is-helping-4-h-youth-development',
#    'urlToImage': 'https://photos5.appleinsider.com/gallery/60768-125080-000-lede-teaching-xl.jpg',
#    'publishedAt': '2024-08-21T13:33:52Z',
#    'content': 'Mark Light has introduced thousands of young people to Apple technology through bus events in rural, suburban, and urban communities across Ohio. (Source: Apple)\r\nAs part of its Community Education I… [+2011 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Geoff Weiss',
#    'title': 'Pumpkin Spice Latte season is coming earlier than ever. Starbucks could use the jolt.',
#    'description': "The PSL debuted in early September back in 2015, though its release has come earlier and earlier. Now it's back on Thursday.",
#    'url': 'https://www.businessinsider.com/starbucks-pumpkin-spice-latte-season-begins-early-2024-8',
#    'urlToImage': 'https://i.insider.com/66c5fc4e1aa2ac29ee32d872?width=1200&format=jpeg',
#    'publishedAt': '2024-08-21T15:53:40Z',
#    'content': "Starbucks' fall menu marks the unofficial start of the season, it said.Starbucks\r\n<ul><li>Pumpkin Spice Lattes are again arriving in the dead of summer.</li><li>There was a time the drink actually la… [+1467 chars]"},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Ben Lovejoy',
#    'title': 'Apple Music free trial back to three months if you sign up now',
#    'description': 'Those who’ve never tried the service can now get an Apple Music free trial for three months, rather than just one.\n\n\n\nThis is the same deal the company offered when it first launched the streaming music service, but it later reduced it to one month … \n\n\n\n mor…',
#    'url': 'https://9to5mac.com/2024/08/20/apple-music-free-trial-three-months/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/08/Apple-Music-free-trial-back-to-three-months.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-20T11:24:47Z',
#    'content': 'Those who’ve never tried the service can now get an Apple Music free trial for three months, rather than just one.\r\nThis is the same deal the company offered when it first launched the streaming musi… [+1620 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Ryan Christoffel',
#    'title': 'Gurman: iOS 18 is ‘final’ with beta 7 until iPhone 16 launch',
#    'description': 'Today Apple released iOS 18 beta 7 to developers. Historically, there would be a beta 8 during the last week of August. However, according to a new X post by Mark Gurman, that’s being called into question.\n\n\n\n more…',
#    'url': 'https://9to5mac.com/2024/08/20/gurman-ios-18-beta-7-is-feature-complete-until-iphone-16-launch/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/08/ios-18-generic-bg.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-20T17:54:30Z',
#    'content': 'Today Apple released iOS 18 beta 7 to developers. Historically, there would be a beta 8 during the last week of August. However, according to a new X post by Mark Gurman, thats being called into ques… [+1371 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Ryan Christoffel',
#    'title': 'Apple releases beta 7 for macOS Sequoia, visionOS 2, and more',
#    'description': 'Apple has a variety of new beta releases available now. Developer beta 7 is rolling out for macOS Sequoia, iPadOS 18, visionOS 2, watchOS 11, and tvOS 18. These join the beta 7 debut for iOS 18.\n\n\n\n more…',
#    'url': 'https://9to5mac.com/2024/08/20/apple-releases-beta-7-for-macos-sequoia-visionos-2-more/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/07/apple-device-lineup.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-20T17:13:12Z',
#    'content': 'Apple has a variety of new beta releases available now. Developer beta 7 is rolling out for macOS Sequoia, iPadOS 18, visionOS 2, watchOS 11, and tvOS 18. These join the beta 7 debut for iOS 18.\r\nWe … [+1621 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Ben Lovejoy',
#    'title': 'UK antitrust investigation into Apple closed for now – but will likely re-open',
#    'description': 'A UK antitrust investigation into Apple has officially closed – despite finding the company to be at fault – after the regulator missed a legal deadline.\n\n\n\nHowever, a case seems almost certain to be re-opened under an upcoming law which will grant new powers…',
#    'url': 'https://9to5mac.com/2024/08/21/uk-antitrust-investigation-into-apple-closed/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/08/UK-antitrust-investigation-into-Apple-closed.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-21T12:11:39Z',
#    'content': 'A UK antitrust investigation into Apple has officially closed despite finding the company to be at fault after the regulator missed a legal deadline.\r\nHowever, a case seems almost certain to be re-op… [+1760 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Ben Lovejoy',
#    'title': 'Apple and 4-H program brings tech to kids, not just agriculture',
#    'description': 'Apple and 4-H are working together to extend the training offered by the youth development network, which is best known for an agricultural focus.\n\n\n\nWith Apple’s support, the network of youth organizations is teaching kids to program in Swift, as well as use…',
#    'url': 'https://9to5mac.com/2024/08/21/apple-and-4-h/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/08/Apple-and-4-H.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-21T13:37:55Z',
#    'content': 'Apple and 4-H are working together to extend the training offered by the youth development network, which is best known for an agricultural focus.\r\nWith Apple’s support, the network of youth organiza… [+2409 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Seth Kurkowski',
#    'title': '9to5Mac Daily: August 20, 2024 – Apple Podcasts on the web, more',
#    'description': 'Listen to a recap of the top stories of the day from\xa09to5Mac. 9to5Mac Daily is available\xa0on iTunes and Apple’s Podcasts app,\xa0Stitcher,\xa0TuneIn,\xa0Google Play, or through our\xa0dedicated RSS feed\xa0for Overcast and other podcast players.\n\n\n\nSponsored by 9to5Mac Daily…',
#    'url': 'https://9to5mac.com/2024/08/20/daily-august-20-2024/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2021/12/9to5Mac-Daily-art-lead.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-20T15:47:00Z',
#    'content': 'Listen to a recap of the top stories of the day from\xa09to5Mac. 9to5Mac Daily is available\xa0on iTunes and Apples Podcasts app,\xa0Stitcher,\xa0TuneIn,\xa0Google Play, or through our\xa0dedicated RSS feed\xa0for Overca… [+848 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Ben Lovejoy',
#    'title': 'iPhone 16 launch will see Apple hit major milestone in reducing dependence on China',
#    'description': 'Apple will this year hit a major milestone in its efforts to reduce its manufacturing dependence on China, according to a new report today.\n\n\n\nWhen the iPhone 16 line-up launches, both Pro models will be made in India within weeks of launch, something the com…',
#    'url': 'https://9to5mac.com/2024/08/20/iphone-16-launch-major-milestone/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/08/Apple-to-hit-major-milestone-in-reducing-dependence-on-China-with-iPhone-16-launch.webp?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-20T11:00:31Z',
#    'content': 'Apple will this year hit a major milestone in its efforts to reduce its manufacturing dependence on China, according to a new report today.\r\nWhen the iPhone 16 line-up launches, both Pro models will … [+2056 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Seth Kurkowski',
#    'title': '9to5Mac Daily: August 21, 2024 – macOS Sequoia features, Apple Watch Series 10 rumors',
#    'description': 'Listen to a recap of the top stories of the day from\xa09to5Mac. 9to5Mac Daily is available\xa0on iTunes and Apple’s Podcasts app,\xa0Stitcher,\xa0TuneIn,\xa0Google Play, or through our\xa0dedicated RSS feed\xa0for Overcast and other podcast players.\n\n\n\nSponsored by 9to5Mac Daily…',
#    'url': 'https://9to5mac.com/2024/08/21/daily-august-21-2024/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2021/12/9to5Mac-Daily-art-lead.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-21T17:49:42Z',
#    'content': 'Listen to a recap of the top stories of the day from\xa09to5Mac. 9to5Mac Daily is available\xa0on iTunes and Apples Podcasts app,\xa0Stitcher,\xa0TuneIn,\xa0Google Play, or through our\xa0dedicated RSS feed\xa0for Overca… [+848 chars]'},
#   {'source': {'id': None, 'name': 'Android Authority'},
#    'author': 'Kaitlyn Cimino',
#    'title': 'Apple Ring wishlist: All the features I want to see',
#    'description': 'The smart ring arena is heating up. Find out everything I would love to see Apple bring to the scene with a potential Apple Ring.',
#    'url': 'https://www.androidauthority.com/apple-ring-3464532/',
#    'urlToImage': 'https://www.androidauthority.com/wp-content/uploads/2024/08/Smart-Rings-Apple-Logo-scaled.jpg',
#    'publishedAt': '2024-08-22T00:01:20Z',
#    'content': 'As smart ring competitions continues to expand, there is still one name seemingly MIA: Apple has yet to join the fray. Weve seen a handful of rumors and suggestions that the company has considered ma… [+5236 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Justin Kahn',
#    'title': 'Deals: Apple Watch Ultra 2 $100 off, M4 iPad Pro $200 off, M2 iPad Air, Magic Keyboards $99 off, more',
#    'description': 'Today’s 9to5Toys Lunch Break is now ready to go with notable deals on Apple Watch Ultra 2, both of the new iPads, Magic keyboards, charging gear, and more. Apple Watch Ultra 2 has returned to Prime Day pricing with all band options now marked down by $100. Mo…',
#    'url': 'https://9to5mac.com/2024/08/20/deals-apple-watch-ultra-2-ipad-pro-magic-keyboards/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/08/Apple-deals-M4-iPAd-Pro-iPad-Air-apple-Watch-Ultra.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-20T15:46:16Z',
#    'content': 'Today’s 9to5Toys Lunch Break is now ready to go with notable deals on Apple Watch Ultra 2, both of the new iPads, Magic keyboards, charging gear, and more. Apple Watch Ultra 2 has returned to Prime D… [+7341 chars]'},
#   {'source': {'id': None, 'name': 'AppleInsider'},
#    'author': 'news@appleinsider.com (Malcolm Owen)',
#    'title': 'How new Apple Music subscribers can get three months for free',
#    'description': "New users can now try out Apple Music for three months for free, instead of the normal one month trial. Here's how to get the super-sized music streaming introductory offer.Apple MusicApple offers people who haven't tried Apple Music before a free month's tri…",
#    'url': 'https://appleinsider.com/articles/24/08/20/how-new-apple-music-subscribers-can-get-three-months-for-free',
#    'urlToImage': 'https://photos5.appleinsider.com/gallery/60748-125056-59342-121119-amplaylists-xl-xl.jpg',
#    'publishedAt': '2024-08-20T13:51:54Z',
#    'content': "Apple Music\r\nNew users can now try out Apple Music for three months for free, instead of the normal one month trial. Here's how to get the super-sized music streaming introductory offer. \r\nApple offe… [+1321 chars]"},
#   {'source': {'id': None, 'name': 'Android Central'},
#    'author': 'bradypsnyder@gmail.com (Brady Snyder)',
#    'title': 'A year later, Pixel 8 Pro users can officially use Zoom Enhance — with lessons learned',
#    'description': 'It took Google nearly a year to ship Zoom Enhance, and it couldn’t do so before announcing the Pixel 8 Pro’s successor.',
#    'url': 'https://www.androidcentral.com/apps-software/lesson-learned-with-google-zoom-enhance-feature',
#    'urlToImage': 'https://cdn.mos.cms.futurecdn.net/AriHAnbWjHYfa6q4QWWvVG-1200-80.jpg',
#    'publishedAt': '2024-08-21T16:31:10Z',
# ...
#    'urlToImage': 'https://cdn.mos.cms.futurecdn.net/wwpNckjnXR6Ypxvx97g8Uh-1200-80.jpg',
#    'publishedAt': '2024-08-22T06:00:20Z',
#    'content': "Google has confirmed that the Pixel Watch 3 is unable to be repaired.\xa0If you have a hardware problem, you'll need to get it replaced. Nobody should be surprised because this is the third version of t… [+3290 chars]"},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Tim Hardwick',
#    'title': "Apple's September Event: New Products to Expect Beyond the iPhone 16",
#    'description': "Apple will hold its annual iPhone event next month, with some signs pointing to September 10 as the date that the company will announce its new flagship iPhone 16 lineup. But it's worth noting that there are a few more products expected to be unveiled as well…",
#    'url': 'https://www.macrumors.com/2024/08/21/apple-september-2024-event-new-products-expected/',
#    'urlToImage': 'https://images.macrumors.com/t/FoiyfgEOp2yV01nDp1wnadXce80=/2048x/article-new/2023/10/Apple-Event-October-2023.jpeg',
#    'publishedAt': '2024-08-21T14:53:39Z',
#    'content': "Apple will hold its annual iPhone event next month, with some signs pointing to September 10 as the date that the company will announce its new flagship iPhone 16 lineup. But it's worth noting that t… [+9418 chars]"},
#   {'source': {'id': None, 'name': 'AppleInsider'},
#    'author': 'news@appleinsider.com (Marko Zivkovic)',
#    'title': "iPhone 16 & iPhone 16 Pro -- What Apple's prototypes say is coming",
#    'description': "Apple's iPhone 16 is less than a month away. Here's what's actually known about the upcoming model based on prototypes and leaked internal designs.Apple's iPhone 16 range is set to usher in a series of meaningful hardware improvements and featuresAs the iPhon…",
#    'url': 'https://appleinsider.com/articles/24/08/20/iphone-16-iphone-16-pro----what-apples-prototypes-say-is-coming',
#    'urlToImage': 'https://photos5.appleinsider.com/gallery/60712-125032-60616-124774-headerip16-xl-xl.jpg',
#    'publishedAt': '2024-08-20T11:02:45Z',
#    'content': "Apple's iPhone 16 range is set to usher in a series of meaningful hardware improvements and features\r\nApple's iPhone 16 is less than a month away. Here's what's actually known about the upcoming mode… [+11651 chars]"},
#   {'source': {'id': None, 'name': 'AppleInsider'},
#    'author': 'news@appleinsider.com (Amber Neely)',
#    'title': 'Customers can now extend AppleCare+ up to 45 days after it expires',
#    'description': 'Apple has recently increased the number of days a customer can extend their AppleCare+ coverage to 45 days, up from the previous 30.AppleCare+ plans can now be extended up to 45 days after they expire in Australia, Austria, Canada, Denmark, Finland, France, G…',
#    'url': 'https://appleinsider.com/articles/24/08/20/customers-can-now-extend-applecare-up-to-45-days-after-it-expires',
#    'urlToImage': 'https://photos5.appleinsider.com/gallery/50275-98761-000-lead-AppleCare+-xl.jpg',
#    'publishedAt': '2024-08-20T20:59:11Z',
#    'content': 'Apple has recently increased the number of days a customer can extend their AppleCare+ coverage to 45 days, up from the previous 30.\r\nAppleCare+ plans can now be extended up to 45 days after they exp… [+662 chars]'},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Aashna Gheewalla',
#    'title': "Save 55% Off a Pair of Beats Solo 3 Headphones Before It's Too Late",
#    'description': 'These Beats Solo 3 headphones are $200 off for a limited time only.',
#    'url': 'https://www.cnet.com/deals/save-55-off-a-pair-of-beats-solo-3-headphones-before-its-too-late/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/15ceb1b129d29a2167eee9bb8d725fec96acf3b5/hub/2024/08/21/d1d2e08c-f2bc-45a8-a83c-96cca68cf4f9/beats-solo-3-wireless-headphones-in-rose-gold.jpg?auto=webp&fit=crop&height=675&width=1200',
#    'publishedAt': '2024-08-21T12:32:00Z',
#    'content': "Beats headphones often find themselves on our list of CNET's favorite\xa0headphones\xa0thanks to a combination of a popular sound signature and great aesthetics. They're often prohibitively expensive thoug… [+940 chars]"},
#   {'source': {'id': None, 'name': 'AppleInsider'},
#    'author': 'news@appleinsider.com (Christine McKee)',
#    'title': "Apple's M3 Pro 14-inch MacBook Pro drops to $1,499, the lowest price ever",
#    'description': 'A record-breaking MacBook Pro 14-inch price drop is knocking a staggering $500 off the M3 Pro model at Amazon, Best Buy and B&H. Grab the deal while supplies last.Save $500 on this 14-inch MacBook Pro.To snap up the deal while supplies last, head over to B&H …',
#    'url': 'https://appleinsider.com/articles/24/08/20/apples-m3-pro-14-inch-macbook-pro-drops-to-1499-the-lowest-price-ever',
#    'urlToImage': 'https://photos5.appleinsider.com/gallery/60757-125067-14-inch-macbook-pro-m3-pro-1499-copy-xl.jpg',
#    'publishedAt': '2024-08-20T20:57:29Z',
#    'content': 'Save $500 on this 14-inch MacBook Pro.\r\nA record-breaking MacBook Pro 14-inch price drop is knocking a staggering $500 off the M3 Pro model at Amazon, Best Buy and B&amp;H. Grab the deal while suppli… [+1152 chars]'},
#   {'source': {'id': None, 'name': 'AppleInsider'},
#    'author': 'news@appleinsider.com (Malcolm Owen)',
#    'title': "Latest iOS 18 beta is 'final' for all but the iPhone 16 models",
#    'description': "The seventh developer beta of iOS 18 may be the same build that iPhone owners will upgrade to, as it is apparently finalized for features for current-generation models.A render of the iPhone 16Apple's lengthy list of features and changes it is bringing to the…",
#    'url': 'https://appleinsider.com/articles/24/08/20/latest-ios-18-beta-is-final-for-all-but-the-iphone-16-models',
#    'urlToImage': 'https://photos5.appleinsider.com/gallery/60755-125065-iphone-16-ios-xl.jpg',
#    'publishedAt': '2024-08-20T18:50:43Z',
#    'content': 'A render of the iPhone 16\r\nLast updated 10 minutes ago\r\nThe seventh developer beta of iOS 18 may be the same build that iPhone owners will upgrade to, as it is apparently finalized for features for c… [+1492 chars]'},
#   {'source': {'id': None, 'name': 'Phandroid - News for Android'},
#    'author': 'Tyler Lee',
#    'title': 'iPhone 16 launch date leaked!',
#    'description': 'According to the latest rumors, here is when we can expect Apple to officially launch the iPhone 16 series next month.\nThe post iPhone 16 launch date leaked! appeared first on Phandroid.',
#    'url': 'https://phandroid.com/2024/08/20/iphone-16-launch-date-leaked/',
#    'urlToImage': 'https://phandroid.com/wp-content/uploads/2023/12/iPhone-12-Pro-Colors.jpg',
#    'publishedAt': '2024-08-20T10:17:30Z',
#    'content': 'The iPhone 16 launch is coming soon. When? We dont know for sure. However, a post on X by Majin Bu claims that according to their sources, the iPhone 16 will be officially announced on the 10th of Se… [+1179 chars]'},
#   {'source': {'id': None, 'name': 'Phandroid - News for Android'},
#    'author': 'Tyler Lee',
#    'title': 'Apple’s foldable plans have been delayed…yet again!',
#    'description': 'Apple was rumored to launch a new foldable device in the coming years, but now a new report suggests it could be delayed further.\nThe post Apple’s foldable plans have been delayed…yet again! appeared first on Phandroid.',
#    'url': 'https://phandroid.com/2024/08/22/apples-foldable-plans-have-been-delayed-yet-again/',
#    'urlToImage': 'https://phandroid.com/wp-content/uploads/2021/06/iPad-Pro-2021-with-Android-Figures.jpg',
#    'publishedAt': '2024-08-22T11:14:12Z',
#    'content': 'Ever since Samsung burst onto the scene with their foldables, many have been wondering if Apple will follow suit. There have been rumors that Apple is working on a foldable device, where past rumors … [+1313 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Ryan Christoffel',
#    'title': 'iPhone 17 Air won’t be the best iPhone, but it will be the future',
#    'description': 'Apple’s iPhone 17 lineup will be weird. We’re just weeks away from the iPhone 16 launch, but it’s 2025’s models at the center of lots of rumors. Specifically, the ultra-slim ‘Air’ model stands to shake up the iPhone 17 lineup. Here’s why next year’s innovativ…',
#    'url': 'https://9to5mac.com/2024/08/20/iphone-17-air-wont-be-the-best-iphone-but-it-will-be-the-future/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/08/iphone-17-air.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-20T20:43:42Z',
#    'content': 'Apples iPhone 17 lineup will be weird. Were just weeks away from the iPhone 16 launch, but its 2025s models at the center of lots of rumors. Specifically, the ultra-slim Air model stands to shake up … [+3437 chars]'},
#   {'source': {'id': None, 'name': 'Small Business Trends'},
#    'author': 'Joshua Sophy',
#    'title': 'Apple Announces New NFC In-App Transaction Capabilities for Developers Starting with iOS 18.1',
#    'description': 'Apple says developers have new NFC in-app transaction capabilities with the release of a new system update.',
#    'url': 'https://smallbiztrends.com/apple-developers-nfc-in-app-transactions/',
#    'urlToImage': 'https://smallbiztrends.com/wp-content/themes/sahifa/images/logo-full.jpg',
#    'publishedAt': '2024-08-20T15:43:21Z',
#    'content': 'Apple has announced that starting with the upcoming iOS 18.1 release, developers will be able to offer NFC contactless transactions directly within their own apps using the Secure Element (SE), separ… [+2097 chars]'},
#   {'source': {'id': None, 'name': 'iMore'},
#    'author': 'alexblake.imore@gmail.com (Alex Blake)',
#    'title': 'Control Center has been supercharged in iOS 18 — here’s how to get the most from it',
#    'description': "In iOS 18, Apple has updated Control Center with new tools and features. Here's how to use them all.",
#    'url': 'https://www.imore.com/ios/control-center-has-been-supercharged-in-ios-18-heres-how-to-get-the-most-from-it',
#    'urlToImage': 'https://cdn.mos.cms.futurecdn.net/K3B2shCVUowLKwrH64jRXR-1200-80.jpg',
#    'publishedAt': '2024-08-20T10:12:27Z',
#    'content': 'The iOS 18 update has brought a lot of changes to all the best iPhones, and one of the most interesting – and wide-ranging – is what’s happened to Control Center. Apple’s quick-access dashboard has h… [+6108 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Juli Clover',
#    'title': 'App Store VP Departs As Apple Prepares for Organizational Changes',
#    'description': 'App Store vice president Matt Fischer is set to leave the company as Apple prepares for an \u200cApp Store\u200c reorganization to deal with regulatory changes, reports Bloomberg.\n\n\n\n\n\nApple plans to split its \u200cApp Store\u200c group into two teams, one that handles the \u200cApp…',
#    'url': 'https://www.macrumors.com/2024/08/21/app-store-organizational-changes/',
#    'urlToImage': 'https://images.macrumors.com/t/Z4nU2dRocDnr4NPvf-sGNedmPGA=/2250x/article-new/2022/01/iOS-App-Store-General-Feature-JoeBlue.jpg',
#    'publishedAt': '2024-08-21T20:11:59Z',
#    'content': 'App Store vice president Matt Fischer is set to leave the company as Apple prepares for an \u200cApp Store\u200c reorganization to deal with regulatory changes, reports Bloomberg.\r\nApple plans to split its \u200cAp… [+1029 chars]'},
#   {'source': {'id': None, 'name': 'Yanko Design'},
#    'author': 'Sarang Sheth',
#    'title': 'The MERAKI Espresso Machine is what you get if Apple and Dyson collaborated to design a coffee maker',
#    'description': 'The MERAKI Espresso Machine is what you get if Apple and Dyson collaborated to design a coffee makerA clean design, flawless and silent operation, and perfect results with just the right amount of tech. That’s what the Meraki promises, as compared to...',
#    'url': 'https://www.yankodesign.com/2024/08/20/the-meraki-espresso-machine-is-what-you-get-if-apple-and-dyson-collaborated-to-design-a-coffee-maker/',
#    'urlToImage': 'https://www.yankodesign.com/images/design_news/2024/08/the-meraki-espresso-machine-is-what-you-get-if-apple-and-dyson-collaborated-to-design-a-coffee-maker/Meraki_Ultimate_Espresso_Machine_hero.jpg',
#    'publishedAt': '2024-08-21T01:45:23Z',
#    'content': 'A clean design, flawless and silent operation, and perfect results with just the right amount of tech. That’s what the Meraki promises, as compared to other espresso machines which can be cumbersome,… [+7038 chars]'},
#   {'source': {'id': None, 'name': 'Android Authority'},
#    'author': 'Ryan Haines',
#    'title': 'The Google Pixel 9 Pro XL is my favorite iPhone ever',
#    'description': "Put away your pitchforks, I don't want a Pixel 9 Pro XL that runs iOS. Instead, I think Google finally made a flagship to tempt Apple users.",
#    'url': 'https://www.androidauthority.com/google-pixel-9-pro-xl-iphone-3473381/',
#    'urlToImage': 'https://www.androidauthority.com/wp-content/uploads/2024/08/Google-Pixel-9-Pro-XL-rear-hero.jpg',
#    'publishedAt': '2024-08-21T17:00:32Z',
#    'content': 'Now that Pixel and iPhone fans are mad at me, Ill say it again. The Pixel 9 Pro XL is by far the best iPhone ever made. Yes, that means it looks and feels more like an iPhone than ever, but Im not su… [+10406 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Juli Clover',
#    'title': 'Apple Seeds Seventh Beta of tvOS 18 to Developers',
#    'description': 'Apple today seeded the seventh beta of the upcoming tvOS 18 refresh to developers for testing purposes, with the beta coming a week after the sixth beta came out.\n\n\n\n\n\nRegistered developers are able to download the tvOS 18 update by opting in to the beta thro…',
#    'url': 'https://www.macrumors.com/2024/08/20/apple-seeds-tvos-18-beta-7/',
#    'urlToImage': 'https://images.macrumors.com/t/GAyquGnnVSnhxBeZ-t47PVsJQ04=/2500x/article-new/2024/06/apple-tv-4k-new-orange.jpg',
#    'publishedAt': '2024-08-20T17:02:00Z',
#    'content': 'Apple today seeded the seventh beta of the upcoming tvOS 18 refresh to developers for testing purposes, with the beta coming a week after the sixth beta came out.\r\nRegistered developers are able to d… [+947 chars]'},
#   {'source': {'id': None, 'name': 'Techdirt'},
#    'author': 'Gretchen Heckmann',
#    'title': 'Daily Deal: 2-in-1 Keychain Wireless Charger for iPhone and Apple Watch',
#    'description': 'This 2-in-1 Keychain Wireless Charger with 2,500mAh battery will charge your Apple Watch 3-5 times on a full charge. Its magnetic design ensures perfect alignment and it works seamlessly with all Apple Watch series. It features Type-C port for versatile charg…',
#    'url': 'https://www.techdirt.com/2024/08/21/daily-deal-2-in-1-keychain-wireless-charger-for-iphone-and-apple-watch-2/',
#    'urlToImage': 'https://www.techdirt.com/wp-content/themes/techdirt/assets/images/td-rect-logo-white.png',
#    'publishedAt': '2024-08-21T17:53:45Z',
#    'content': 'from the good-deals-on-cool-stuff dept\r\nThis 2-in-1 Keychain Wireless Charger with 2,500mAh battery will charge your Apple Watch 3-5 times on a full charge. Its magnetic design ensures perfect alignm… [+389 chars]'},
#   {'source': {'id': None, 'name': 'GSMArena.com'},
#    'author': 'Michail',
#    'title': 'Kuo: Apple foldable delayed, again',
#    'description': 'Foldable phones have been developing rapidly in the last five years and some manufacturers are even experimenting with larger form factors like laptops while others like Apple have yet to dip their toes in the foldable market. There’s no shortage of rumors cl…',
#    'url': 'https://www.gsmarena.com/kuo_apple_foldable_delayed_again-news-64235.php',
#    'urlToImage': 'https://fdn.gsmarena.com/imgroot/news/24/08/apple-foldable-delayed-yet-again/-952x498w6/gsmarena_00.jpg',
#    'publishedAt': '2024-08-22T10:33:01Z',
#    'content': 'Foldable phones have been developing rapidly in the last five years and some manufacturers are even experimenting with larger form factors like laptops while others like Apple have yet to dip their t… [+997 chars]'}]}

# %%
def main(company):
    data = get_data(company)
    write(data, company)

# %%
test = json.dumps(data_raw['articles'])

# %%
rows_to_insert = []
for x in data_raw['articles']:
    x['source'] = x['source']['name']
    rows_to_insert.append(x)

# %%
data_raw
# Out:
# {'status': 'ok',
#  'totalResults': 1784,
#  'articles': [{'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Lawrence Bonk',
#    'title': 'Apple event rumor roundup: What to expect at the iPhone 16 keynote',
#    'description': 'The biggest day of the tech world’s fall calendar is nearly here: Apple’s iPhone 16 event will take place sometime in September. The company typically does it on a Tuesday during the first half of the month, so September 10 is a safe bet. No matter when it ha…',
#    'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_7de77318-ab44-441e-a0d7-b47c8388fcdd',
#    'urlToImage': None,
#    'publishedAt': '2024-08-20T19:23:47Z',
#    'content': "If you click 'Accept all', we and our partners, including 237 who are part of the IAB Transparency &amp; Consent Framework, will also store and/or access information on a device (in other words, use … [+678 chars]"},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Antonio G. Di Benedetto',
#    'title': 'Nomad’s latest Base One Max 3-in-1 charger is more than $50 off',
#    'description': 'The second-gen Nomad Base One Max can simultaneously charge a MagSafe-ready iPhone, AirPods, and an Apple Watch — and it’s on sale this week for just $119.',
#    'url': 'https://www.theverge.com/2024/8/20/24224722/nomad-base-one-max-3-in-1-magsafe-magnetic-charger-deal-sale',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/H2oyewvIg0Q1Dbkp77vAXpoPo7w=/0x0:1758x1258/1200x628/filters:focal(879x629:880x630)/cdn.vox-cdn.com/uploads/chorus_asset/file/25251597/Nomad_Base_One_Max_3_in_1_MagSafe_Charger.jpg',
#    'publishedAt': '2024-08-20T21:14:26Z',
#    'content': 'Nomads latest Base One Max 3-in-1 charger is more than $50 off\r\nNomads latest Base One Max 3-in-1 charger is more than $50 off\r\n / For $119, you get a very fancy MagSafe charger for your iPhone, Appl… [+1750 chars]'},
#   {'source': {'id': None, 'name': '[Removed]'},
#    'author': None,
#    'title': '[Removed]',
#    'description': '[Removed]',
#    'url': 'https://removed.com',
#    'urlToImage': None,
#    'publishedAt': '1970-01-01T00:00:00Z',
#    'content': '[Removed]'},
#   {'source': {'id': None, 'name': '[Removed]'},
#    'author': None,
#    'title': '[Removed]',
#    'description': '[Removed]',
#    'url': 'https://removed.com',
#    'urlToImage': None,
#    'publishedAt': '1970-01-01T00:00:00Z',
#    'content': '[Removed]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Tim Hardwick',
#    'title': 'Apple Music Offering Free Three-Month Trial for a Limited Time',
#    'description': "Apple is offering an extended three-month free Apple Music trial for new users over the summer, provided they haven't been a subscriber to the streaming service before.\n\n\n\n\n\n\u200cApple Music\u200c typically offers a one-month free trial for new subscribers since it wa…",
#    'url': 'https://www.macrumors.com/2024/08/20/apple-music-free-three-month-trial/',
#    'urlToImage': 'https://images.macrumors.com/t/cBpeJ95wekMRm8-YbPPJQhJrDsY=/1920x/article-new/2024/08/apple-music.jpg',
#    'publishedAt': '2024-08-20T12:56:29Z',
#    'content': "Apple is offering an extended three-month free Apple Music trial for new users over the summer, provided they haven't been a subscriber to the streaming service before.\r\nApple Music typically offers … [+892 chars]"},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Tim Hardwick',
#    'title': 'macOS Sequoia Has New FaceTime Backgrounds Showcasing Apple Park',
#    'description': "Apple in the second beta of macOS Sequoia 15.1 has added a set of new backgrounds for FaceTime calls that showcase features of Apple Park.\n\n\n\n\n\nThere are nine backgrounds in all, featuring iconic locations around the company's circular headquarters in Cuperti…",
#    'url': 'https://www.macrumors.com/2024/08/20/macos-sequoia-new-facetime-backgrounds/',
#    'urlToImage': 'https://images.macrumors.com/t/AH7LgCRE82dai24GwTtpnidUEIg=/1920x/article-new/2024/08/macos-sequoia-facetime-backgrounds.jpg',
#    'publishedAt': '2024-08-20T10:30:10Z',
#    'content': 'Apple in the second beta of macOS Sequoia 15.1 has added a set of new backgrounds for FaceTime calls that showcase features of Apple Park.\r\nThere are nine backgrounds in all, featuring iconic locatio… [+1353 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Juli Clover',
#    'title': 'Apple Releases New Firmware for Beats Studio Pro',
#    'description': 'Apple today released new firmware for the Beats Studio Pro over-ear headphones. The Beats Studio Pro can be updated to firmware version 10M7529, up from the prior 2B68 firmware that was installed on the headphones at launch. Note that the 10M7529 firmware num…',
#    'url': 'https://www.macrumors.com/2024/08/20/apple-releases-new-firmware-for-beats-studio-pro/',
#    'urlToImage': 'https://images.macrumors.com/t/Culu7KPCVbwscCzTNrTy9UXgBNg=/1600x/article-new/2023/07/beats-studio-pro-iphone.jpg',
#    'publishedAt': '2024-08-20T22:30:39Z',
#    'content': 'Apple today released new firmware for the Beats Studio Pro over-ear headphones. The Beats Studio Pro can be updated to firmware version 10M7529, up from the prior 2B68 firmware that was installed on … [+1358 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Juli Clover',
#    'title': 'Apple Seeds Seventh Beta of macOS Sequoia to Developers',
#    'description': 'Apple today seeded the seventh beta of upcoming an upcoming macOS 15 Sequoia update to developers for testing purposes, with the software coming a week after the release of the sixth beta.\n\n\n\n\n\nRegistered developers can opt-in to the macOS Sequoia beta throug…',
#    'url': 'https://www.macrumors.com/2024/08/20/apple-seeds-macos-sequoia-beta-7/',
#    'urlToImage': 'https://images.macrumors.com/t/zZbcqD0-kgQ9SCr6AnSkKJIiULE=/2500x/article-new/2024/06/macOS-Sequoia-Feature.jpg',
#    'publishedAt': '2024-08-20T17:08:11Z',
#    'content': 'Apple today seeded the seventh beta of upcoming an upcoming macOS 15 Sequoia update to developers for testing purposes, with the software coming a week after the release of the sixth beta.\r\nRegistere… [+1391 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Tim Hardwick',
#    'title': 'Kuo: Folding All-Screen MacBook Delayed Until Late 2027 At the Earliest',
#    'description': "Apple's rumored foldable MacBook won't arrive until the end of 2027 or 2028 at the earliest because of technical challenges, according to the latest prediction by Apple analyst Ming-Chi Kuo.\n\n\n\nConcept by Astropad\n\nPrevious reports from display industry analy…",
#    'url': 'https://www.macrumors.com/2024/08/22/kuo-foldable-macbook-delayed-2027/',
#    'urlToImage': 'https://images.macrumors.com/t/zKktJKfU2gMwxRwH3vDHqQb2HYs=/1600x/article-new/2024/05/Foldable-Screen-MacBook-Concept-Astropad.jpg',
#    'publishedAt': '2024-08-22T10:50:25Z',
#    'content': "Apple's rumored foldable MacBook won't arrive until the end of 2027 or 2028 at the earliest because of technical challenges, according to the latest prediction by Apple analyst Ming-Chi Kuo.\r\nPreviou… [+2521 chars]"},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Juli Clover',
#    'title': 'Nomad Launches Stand One Max Qi2 Charging Hub for iPhone, Apple Watch and AirPods',
#    'description': 'Nomad today introduced its latest multi-device charger, debuting a new version of the Stand One Max with Qi2 support. Rather than continuing to use MagSafe, Nomad is transitioning to Qi2, the latest Qi charging standard that is able to charge iPhones at \u200cMagS…',
#    'url': 'https://www.macrumors.com/2024/08/21/nomad-qi2-stand-one-max/',
#    'urlToImage': 'https://images.macrumors.com/t/MldafrVnP26lcgWrqzCIxDrqzQE=/2000x/article-new/2024/08/nomad-stand-one-max-2.jpg',
#    'publishedAt': '2024-08-21T16:00:00Z',
#    'content': 'Nomad today introduced its latest multi-device charger, debuting a new version of the Stand One Max with Qi2 support. Rather than continuing to use MagSafe, Nomad is transitioning to Qi2, the latest … [+2505 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Emma Roth',
#    'title': 'Authors sue Anthropic for training AI using pirated books',
#    'description': 'The proposed class action suit claims Anthropic used pirated books sourced from a dataset called The Pile to train its family of Claude AI models.',
#    'url': 'https://www.theverge.com/2024/8/20/24224450/anthropic-copyright-lawsuit-pirated-books-ai',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/vNMfM5bpGgs8ixA4ksEjBydTG-4=/0x0:2040x1360/1200x628/filters:focal(1020x680:1021x681)/cdn.vox-cdn.com/uploads/chorus_asset/file/25469772/STK269_ANTHROPIC_A.jpg',
#    'publishedAt': '2024-08-20T16:54:37Z',
#    'content': 'Authors sue Anthropic for training AI using pirated books\r\nAuthors sue Anthropic for training AI using pirated books\r\n / The authors accuse Anthropic of copyright infringement for training its AI mod… [+2357 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Tim Hardwick',
#    'title': "New iPhone 16 Thermal Design High on Buyers' Wishlist, Survey Suggests",
#    'description': 'A recent survey conducted by SellCell suggests that a significant majority of iPhone users are planning to upgrade to the upcoming iPhone 16 series, with many expressing a preference for a better thermal design to prevent overheating issues. \n\n\n\n\n\nThe survey,…',
#    'url': 'https://www.macrumors.com/2024/08/20/iphone-16-pre-launch-survey-overheating/',
#    'urlToImage': 'https://images.macrumors.com/t/dQzfQzCqjlEJdrgq3QVPbLFzfeM=/3532x/article-new/2023/09/iPhone-16-Side-Feature.jpg',
#    'publishedAt': '2024-08-20T11:49:42Z',
#    'content': 'A recent survey conducted by SellCell suggests that a significant majority of iPhone users are planning to upgrade to the upcoming iPhone 16 series, with many expressing a preference for a better the… [+2323 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Tim Hardwick',
#    'title': 'UK Antitrust Watchdog Closes Apple App Store Investigation, Case to Be Reconsidered Under New Digital Rules Regime',
#    'description': "The UK's Competition and Market Authority (CMA) today announced it had closed an investigation into Apple's App Store policies, as it expects to consider the concerns under a new digital markets competition regime which is expected to come into force later th…",
#    'url': 'https://www.macrumors.com/2024/08/21/uk-antitrust-watchdog-closes-probe-app-store/',
#    'urlToImage': 'https://images.macrumors.com/t/oNd60UHBH70Ze0PtFNPGSCa0cKQ=/1794x/article-new/2021/06/app-store-blue-banner-uk-fixed.jpg',
#    'publishedAt': '2024-08-21T11:37:01Z',
#    'content': "The UK's Competition and Market Authority (CMA) today announced it had closed an investigation into Apple's App Store policies, as it expects to consider the concerns under a new digital markets comp… [+2493 chars]"},
#   {'source': {'id': None, 'name': '[Removed]'},
#    'author': None,
#    'title': '[Removed]',
#    'description': '[Removed]',
#    'url': 'https://removed.com',
#    'urlToImage': None,
#    'publishedAt': '1970-01-01T00:00:00Z',
#    'content': '[Removed]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Mitchel Broussard',
#    'title': "Amazon's New Accessory Sale Includes Deals on AirTag, Eufy SmartTrack, and Jackery Power Stations",
#    'description': "Today we're tracking a big collection of discounts on Bluetooth trackers and portable power stations, including Apple's own AirTag, Anker's more affordable brand of Eufy SmartTrack accessories, and power stations from Jackery. All of these deals can be found …",
#    'url': 'https://www.macrumors.com/2024/08/21/amazon-airtag-eufy-jackery/',
#    'urlToImage': 'https://images.macrumors.com/t/CYPlhzPvRwbX-M884hlokABZGto=/2250x/article-new/2024/08/jackery-blue.jpg',
#    'publishedAt': '2024-08-21T15:17:16Z',
#    'content': "Today we're tracking a big collection of discounts on Bluetooth trackers and portable power stations, including Apple's own AirTag, Anker's more affordable brand of Eufy SmartTrack accessories, and p… [+1926 chars]"},
#   {'source': {'id': None, 'name': 'PCMag.com'},
#    'author': 'PC Mag',
#    'title': 'Amazon Deals of The Day: A Rare 40% Discount on an Apple iPad (9th Gen)',
#    'description': "You can also score the latest Amazon Echo Spot (2024) for 30% less (the lowest price we've seen all year on this model) and a 32-inch Amazon Fire TV 2-Series...",
#    'url': 'https://www.pcmag.com/deals/amazon-deals-of-the-day-apple-ipad-9th-gen-august-21',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/r8aHfq_XVV3Ubk3ik3AYxA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://media.zenfs.com/en/pc_mag_263/ad087856c4fa7cd9af3361187334acef',
#    'publishedAt': '2024-08-21T15:00:09Z',
#    'content': 'The powerhouse iPad (9th Gen) is now 40% off, which for any Apple product, is an amazing discount. This model features the A13 Bionic chip, a stunning 10.2-inch True Tone display, and a 12MP ultra-wi… [+2716 chars]'},
#   {'source': {'id': None, 'name': 'Android Central'},
#    'author': 'jerry.hildenbrand@futurenet.com (Jerry Hildenbrand)',
#    'title': 'Using plastic packaging is dumb. Google just stopped doing it.',
#    'description': "Diamonds are forever. So is plastic. Let's stop using it as a packing material.",
#    'url': 'https://www.androidcentral.com/phones/google-just-stopped-using-plastic-packaging',
#    'urlToImage': 'https://cdn.mos.cms.futurecdn.net/Hv8oQ6qzM8gwVwe3J7sUwW-1200-80.jpg',
#    'publishedAt': '2024-08-20T18:26:52Z',
#    'content': "Google quietly announced something that most people aren't going to pay any attention to, even though we all should; it's one of the most important things the company has done.\r\nIt has stopped using … [+3083 chars]"},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Juli Clover',
#    'title': 'OnePlus Buds Pro 3 vs. AirPods Pro 2',
#    'description': "Chinese company OnePlus is debuting new earbuds today, with a feature set that pits them against the AirPods Pro. The OnePlus Buds Pro 3 look and sound a lot like Apple's AirPods, and while they lack some of the Apple-esque magic integration, they're more aff…",
#    'url': 'https://www.macrumors.com/2024/08/20/oneplus-buds-pro-3-vs-airpods-pro-2/',
#    'urlToImage': 'https://images.macrumors.com/t/LruKR3Eo15neLHaTwhJR3MCkp-Q=/2428x/article-new/2024/08/OnePlus-Buds-Pro-3-Thumb-2.jpg',
#    'publishedAt': '2024-08-20T17:58:01Z',
#    'content': "Chinese company OnePlus is debuting new earbuds today, with a feature set that pits them against the AirPods Pro. The OnePlus Buds Pro 3 look and sound a lot like Apple's AirPods, and while they lack… [+2375 chars]"},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Juli Clover',
#    'title': 'iPhone 15 Pro Max: One Year Review',
#    'description': "It's been almost a year since the iPhone 15 models were released, so MacRumors videographer Dan Barbera decided to do a one-year check-in review on the iPhone 15 Pro Max to see how it's performed over the last 12 months.\n\n\n\n\r\nSubscribe to the MacRumors YouTub…",
#    'url': 'https://www.macrumors.com/2024/08/21/iphone-15-pro-max-one-year-review/',
#    'urlToImage': 'https://images.macrumors.com/t/N8cDn-8zPTMw5asPHnHyVE4Lfv0=/2500x/article-new/2024/08/iPhone-15-Pro-Max-1-Year-Later-Thumb-3.jpg',
#    'publishedAt': '2024-08-21T17:53:30Z',
#    'content': "It's been almost a year since the iPhone 15 models were released, so MacRumors videographer Dan Barbera decided to do a one-year check-in review on the iPhone 15 Pro Max to see how it's performed ove… [+2251 chars]"},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Ryan Christoffel',
#    'title': 'Apple Watch Ultra 3 may be a harder sell than ever before',
#    'description': 'In a few short weeks, Apple will hold its iPhone 16 event. Though not the star of the show, new Apple Watch models will debut alongside the iPhone. An Apple Watch Series 10 and Apple Watch Ultra 3 are coming. But there’s a problem: the Series 10 is set to gai…',
#    'url': 'https://9to5mac.com/2024/08/20/apple-watch-ultra-3-may-be-a-harder-sell-than-ever-before/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2022/09/Apple-Watch-Ultra-Release.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-20T15:26:30Z',
#    'content': 'In a few short weeks, Apple will hold its iPhone 16 event. Though not the star of the show, new Apple Watch models will debut alongside the iPhone. An Apple Watch Series 10 and Apple Watch Ultra 3 ar… [+2885 chars]'},
#   {'source': {'id': None, 'name': '[Removed]'},
#    'author': None,
#    'title': '[Removed]',
#    'description': '[Removed]',
#    'url': 'https://removed.com',
#    'urlToImage': None,
#    'publishedAt': '1970-01-01T00:00:00Z',
#    'content': '[Removed]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Filipe Espósito',
#    'title': 'Could Apple hold the iPhone 16 event a week earlier than expected?',
#    'description': 'It’s no secret that Apple usually announces new in September with a special event at Apple Park. My colleague Chance Miller had already speculated here on 9to5Mac about a possible date for the iPhone 16 event this year. However, what if Apple held this year’s…',
#    'url': 'https://9to5mac.com/2024/08/20/apple-iphone-16-september-event/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/08/tim-cook-iphone-apple-event.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-20T19:45:35Z',
#    'content': 'It’s no secret that Apple usually announces new iPhones in September with a special event at Apple Park. My colleague Chance Miller had already speculated here on 9to5Mac about a possible date for th… [+2505 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Kyle Barr',
#    'title': 'The New Samsung Odyssey Could Fix the Most Annoying Thing About 3D Gaming',
#    'description': "Samsung promises there’s a 27-inch and 37-inch Odyssey 3D monitor coming later this year, though we don't know how expensive it will be.",
#    'url': 'https://gizmodo.com/the-new-samsung-odyssey-could-fix-the-most-annoying-thing-about-3d-gaming-2000489287',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2024/08/Samsung-TVs-and-Displays-Odyssey-3D-Gamescom-2024_main1.jpeg',
#    'publishedAt': '2024-08-21T14:25:22Z',
#    'content': 'If youre a Samsung Odyssey monitor fan, you already have plenty of expensive options for 4K gaming with OLEDs like the G6 and G8. Samsung now says that 2D screens is old hat. The company is soon goin… [+2912 chars]'},
#   {'source': {'id': None, 'name': 'AppleInsider'},
#    'author': 'news@appleinsider.com (Christine McKee)',
#    'title': 'Amazon clears out Apple Watch inventory, grab the Series 9 for $299 & Ultra 2 for $699',
#    'description': 'Amazon is slashing Apple Watch prices ahead of the September Apple event, resulting in the return of Prime Day pricing on multiple Series 9 and Ultra 2 styles.Amazon is blowing out Apple Watch inventory.As September inches closer, the Apple Watch deals are he…',
#    'url': 'https://appleinsider.com/articles/24/08/20/amazon-clears-out-apple-watch-inventory-grab-the-series-9-for-299-ultra-2-for-699',
#    'urlToImage': 'https://photos5.appleinsider.com/gallery/60747-125055-apple-watch-sale-2024-xl.jpg',
#    'publishedAt': '2024-08-20T14:06:55Z',
#    'content': 'Amazon is blowing out Apple Watch inventory.\r\nAmazon is slashing Apple Watch prices ahead of the September Apple event, resulting in the return of Prime Day pricing on multiple Series 9 and Ultra 2 s… [+508 chars]'},
#   {'source': {'id': None, 'name': 'AppleInsider'},
#    'author': 'news@appleinsider.com (Mike Wuerthele and Wes Hilliard)',
#    'title': 'Apple Vision Pro review: six month stasis',
#    'description': 'After six months with Apple Vision Pro, things feel stuck. A glacial rollout of immersive content, a lack of native apps, and no word of Apple Intelligence make the $3,500 product harder to swallow.Apple Vision Pro review: stuck in placeApple Vision Pro is fr…',
#    'url': 'https://appleinsider.com/articles/24/08/20/apple-vision-pro-review-six-month-stasis',
#    'urlToImage': 'https://photos5.appleinsider.com/gallery/60333-124789-VP29-xl.jpg',
#    'publishedAt': '2024-08-20T12:09:49Z',
#    'content': 'Apple Vision Pro review: stuck in place\r\nAfter six months with Apple Vision Pro, things feel stuck. A glacial rollout of immersive content, a lack of native apps, and no word of Apple Intelligence ma… [+23497 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Chance Miller',
#    'title': 'App Store VP departing Apple amid broader restructuring',
#    'description': 'Apple’s App Store vice president is leaving the company in October, according to a new report from Bloomberg. \n\n\n\nThe structure of the App Store team is also being split into two teams, a change implemented by Phil Schiller in response to the ever-changing Ap…',
#    'url': 'https://9to5mac.com/2024/08/21/app-store-vp-departing-apple-amid-broader-restructuring/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/06/track-manage-apple-app-store-subscriptions.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-21T19:54:59Z',
#    'content': 'Apple’s App Store vice president is leaving the company in October, according to a new report from Bloomberg. \r\nThe structure of the App Store team is also being split into two teams, a change implem… [+2081 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Zac Hall',
#    'title': 'Double tappin’ watchOS 11 on Apple Watch Series 9',
#    'description': 'Apple Watch and Ultra 2 introduce the double tap gesture, and I’ve found that the upcoming watchOS 11 update makes the hands-free input method more useful.\n\n\n\nDouble tap lets you interact with the Apple Watch by doing a two-tap gesture with your thumb and fin…',
#    'url': 'https://9to5mac.com/2024/08/20/double-tap-smart-stack-watchos-11-apple-watch/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/06/Screenshot-2024-06-10-at-1.43.20-PM.webp?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-20T18:07:41Z',
#    'content': 'Apple Watch Series 9 and Ultra 2 introduce the double tap gesture, and I’ve found that the upcoming watchOS 11 update makes the hands-free input method more useful.\r\nDouble tap lets you interact with… [+5131 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Chance Miller',
#    'title': 'macOS Sequoia includes new Apple Park backgrounds for video conferencing apps',
#    'description': 'As we approach the public release of macOS Sequoia this fall, Apple continues to add new features. In the latest macOS Sequoia betas, there are nine new built-in backgrounds for video conferencing apps that showcase various different parts of Apple Park.\n\n\n\n …',
#    'url': 'https://9to5mac.com/2024/08/20/macos-sequoia-apple-park-backgrounds/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2023/10/apple-park-dusk.jpeg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-20T16:25:21Z',
#    'content': 'As we approach the public release of macOS Sequoia this fall, Apple continues to add new features. In the latest macOS Sequoia betas, there are nine new built-in backgrounds for video conferencing ap… [+1229 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Michael Potuck',
#    'title': 'Nomad launches Stand One Max with Qi2, Apple Watch fast charger, metal and glass design',
#    'description': 'Upgrading its premium charger lineup for Apple devices, Nomad has released the 3rd gen Stand One Max. Built with a metal and glass design, features include Qi2 support with 15W wireless charging, Apple Watch fast charging, and a charger for AirPods. Read on f…',
#    'url': 'https://9to5mac.com/2024/08/21/nomad-launches-stand-one-max-with-qi2-iphone-apple-watch-airpods/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/08/nomad-stand-one-max-3rd-gen.jpeg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-21T16:00:00Z',
#    'content': 'Upgrading its premium charger lineup for Apple devices, Nomad has released the 3rd gen Stand One Max. Built with a metal and glass design, features include Qi2 support with 15W wireless charging, App… [+2812 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Juli Clover',
#    'title': "PSA: There's New Character Bug That Can Cause iPhones to Crash",
#    'description': 'There is a new character bug that can result in a respring on the iPhone or iPad, reports TechCrunch. Typing "":: in the search field after swiping over to the App Library will cause the Springboard to reset, dropping you back at the \u200ciPhone\u200c\'s Lock Screen. A…',
#    'url': 'https://www.macrumors.com/2024/08/21/iphone-character-bug-respring/',
#    'urlToImage': 'https://images.macrumors.com/t/FWFeAmxnHKf7vkk_MCBh9TcNMVg=/1600x/article-new/2023/05/bug-security-vulnerability-issue-fix-larry.jpg',
#    'publishedAt': '2024-08-21T19:25:41Z',
#    'content': 'There is a new character bug that can result in a respring on the iPhone or iPad, reports TechCrunch. Typing "":: in the search field after swiping over to the App Library will cause the Springboard … [+1209 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Ryan Christoffel',
#    'title': 'There’s no beta for Genmoji or AI image generation, and Pixel 9 headlines explain why',
#    'description': 'Today reviews dropped for Google’s AI-packed Pixel 9 phones. Why mention that on an Apple site? Because the headlines Google’s getting help explain why Apple Intelligence’s image generation features are still MIA from the iOS 18.1 beta. In fact, the more head…',
#    'url': 'https://9to5mac.com/2024/08/21/theres-no-beta-for-genmoji-or-ai-image-generation-and-pixel-9-headlines-explain-why/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/08/genmoji-generative-ai.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-21T20:19:00Z',
#    'content': 'Today reviews dropped for Googles AI-packed Pixel 9 phones. Why mention that on an Apple site? Because the headlines Googles getting help explain why Apple Intelligences image generation features are… [+3115 chars]'},
#   {'source': {'id': None, 'name': 'AppleInsider'},
#    'author': 'news@appleinsider.com (William Gallagher)',
#    'title': 'Arm-mounted haptics could make future iPhone notifications more discreet',
#    'description': "Even silent alerts can be audible if an Apple Watch haptic engine is too powerful, but Apple has plans to make notifications entirely private.Detail from the patent. Notice the armband and possibly an Apple Bracelet tooYou're at a meeting and it's time for yo…",
#    'url': 'https://appleinsider.com/articles/24/08/20/arm-mounted-haptics-could-make-future-iphone-notifications-more-discreet',
#    'urlToImage': 'https://photos5.appleinsider.com/gallery/60749-125059-000-lede-haptic-d2-xl.jpg',
#    'publishedAt': '2024-08-20T14:52:59Z',
#    'content': 'Detail from the patent. Notice the armband and possibly an Apple Bracelet too\r\nEven silent alerts can be audible if an Apple Watch haptic engine is too powerful, but Apple has plans to make notificat… [+2972 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Justin Kahn',
#    'title': 'Deals: Apple Watch Series 9 $100 off, M2 MacBook Air $699, Nomad Base One Max MagSafe charger 30% off, and more',
#    'description': 'Your mid-week collection of deals on Apple gear and accessories for them all is now up for grabs down below. The return of $100 price drops across a number of Apple Watch Series 9 configurations are at the ready, but we also have new lows on elevated M3 iMac …',
#    'url': 'https://9to5mac.com/2024/08/21/deals-apple-watch-macbook-air-nomad/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/08/Apple-deals-iMac-Apple-Watch-more.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-21T15:46:36Z',
#    'content': 'Your mid-week collection of deals on Apple gear and accessories for them all is now up for grabs down below. The return of $100 price drops across a number of Apple Watch Series 9 configurations are … [+9370 chars]'},
#   {'source': {'id': None, 'name': 'Macworld'},
#    'author': 'Roman Loyola',
#    'title': 'The M4 Mac mini will be like no other Mac you’ve ever seen',
#    'description': 'Macworld\n\n\n\r\n\n\n\n\n2024 may end up being a big year for Apple’s smallest Mac. While other Macs are rumored to get iterative spec bumps, the Mac mini will reportedly undergo drastic changes–changes that may shift the perception of the device. When all is said an…',
#    'url': 'https://www.macworld.com/article/2427858/the-m4-mac-mini-will-be-like-no-other-mac-youve-ever-seen.html',
#    'urlToImage': 'https://www.macworld.com/wp-content/uploads/2024/08/mac-mini-apple-tv-graphic-1.jpg?quality=50&strip=all&w=1024',
#    'publishedAt': '2024-08-22T10:30:00Z',
#    'content': "Skip to contentType your search and hit enter\r\nWhen you purchase through links in our articles, we may earn a small commission. This doesn't affect our editorial independence\r\n.\r\n2024 may end up bein… [+9830 chars]"},
#   {'source': {'id': None, 'name': 'AppleInsider'},
#    'author': 'news@appleinsider.com (Andrew Orr)',
#    'title': "iCloud storage leads the pack in Apple's services ecosystem",
#    'description': "With hardware sales slowing, Apple shifted to expanding its digital services offerings to generate billions each quarter. One service stands out as the clear leader.iCloud storage leads the pack in Apple's services ecosystemApple has been aggressively expandi…",
#    'url': 'https://appleinsider.com/articles/24/08/21/icloud-storage-leads-the-pack-in-apples-services-ecosystem',
#    'urlToImage': 'https://photos5.appleinsider.com/gallery/60769-125085-icloud-icon-xl.jpg',
#    'publishedAt': '2024-08-21T14:29:55Z',
#    'content': "iCloud storage leads the pack in Apple's services ecosystem\r\nLast updated 17 seconds ago\r\nWith hardware sales slowing, Apple shifted to expanding its digital services offerings to generate billions e… [+2582 chars]"},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Juli Clover',
#    'title': 'iPhone Photography Awards Highlight Best Images of 2024',
#    'description': "Every year, the iPhone Photography Awards (IPPA) selects the best photographs captured with an \u200ciPhone\u200c, and the 2024 award winners were announced today. Many of this year's winning images were taken with Apple's most recent iPhone 15 models.\n\n\n\n\n\nThe grand p…",
#    'url': 'https://www.macrumors.com/2024/08/20/iphone-photography-awards-2024/',
#    'urlToImage': 'https://images.macrumors.com/t/fE5bcTOP5ymqO6mizljgEB7pvy4=/2500x/article-new/2023/09/iPhone-15-Blue-Three-Quarters-Perspective-Camera-Closeup-Feature.jpg',
#    'publishedAt': '2024-08-20T22:42:00Z',
#    'content': "Every year, the iPhone Photography Awards (IPPA) selects the best photographs captured with an \u200ciPhone\u200c, and the 2024 award winners were announced today. Many of this year's winning images were taken… [+932 chars]"},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Reuters Videos',
#    'title': "We are 'cautious bulls' on market -portfolio manager",
#    'description': 'STORY: "We know that the market is not cheap. If we look at forward earnings, it\'s a little bit turn or two higher than historical averages, not aggressively...',
#    'url': 'https://finance.yahoo.com/video/cautious-bulls-market-portfolio-manager-195407752.html',
#    'urlToImage': 'https://media.zenfs.com/en/video.reutersnews.com/1a66d1b4f70e1cd00ab60d1bed1cd09c',
#    'publishedAt': '2024-08-21T19:54:07Z',
#    'content': 'STORY: "We know that the market is not cheap. If we look at forward earnings, it\'s a little bit turn or two higher than historical averages, not aggressively so. So not in a bubble scenario, but it\'s… [+175 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Matthew S. Smith',
#    'title': "The founder of a software-development company says there's a 'huge demand' for training and education applications — extended reality can help",
#    'description': 'Treeview uses augmented- and virtual-reality tools with AI to develop software and metaverse projects. Its clients include Microsoft and Medtronic.',
#    'url': 'https://www.businessinsider.com/treeview-extended-reality-artificial-intelligence-software-development-metaverse-2024-8',
#    'urlToImage': 'https://i.insider.com/66c4e6b4b4912df3ae1d0fd5?width=1200&format=jpeg',
#    'publishedAt': '2024-08-21T16:55:20Z',
#    'content': 'Horacio Torrendell; Getty Images; Alyssa Powell/BI\r\n<ul><li>Treeview is a developer of extended-reality software that serves clients such as Microsoft.</li><li>Its founder spoke with BI about the com… [+8155 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Michael Potuck',
#    'title': 'Here’s Apple’s most popular service in 2024',
#    'description': 'As iPhone sales slow down, Apple’s services become more important to grow the company’s revenue. Looking into which of the company’s offerings are most popular, CIRP has published a report revealing what services Apple customers use.\n\n\n\n more…',
#    'url': 'https://9to5mac.com/2024/08/21/apples-most-popular-service-in-2024/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2021/04/apple-services.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-21T18:04:33Z',
#    'content': 'As iPhone sales slow down, Apple’s services become more important to grow the company’s revenue. Looking into which of the company’s offerings are most popular, CIRP has published a report revealing … [+1203 chars]'},
#   {'source': {'id': None, 'name': 'AppleInsider'},
#    'author': 'news@appleinsider.com (Andrew Orr)',
#    'title': 'Apple leads global mobile market, outpacing competitors in advertising',
#    'description': "Apple continues to dominate the global mobile device market, now securing the top position in programmatic advertising share.Apple leads global mobile market, outpacing competitors in advertisingApple's dominance in the global mobile device market continues, …",
#    'url': 'https://appleinsider.com/articles/24/08/21/apple-leads-global-mobile-market-outpacing-competitors-in-advertising',
#    'urlToImage': 'https://photos5.appleinsider.com/gallery/60774-125099-apple-park-xl.jpg',
#    'publishedAt': '2024-08-21T21:19:38Z',
#    'content': 'Apple leads global mobile market, outpacing competitors in advertising\r\nApple continues to dominate the global mobile device market, now securing the top position in programmatic advertising share.\r\n… [+2325 chars]'},
#   {'source': {'id': None, 'name': 'AppleInsider'},
#    'author': 'news@appleinsider.com (William Gallagher)',
#    'title': 'Apple spotlights how its technology is helping 4-H youth development',
#    'description': 'As part of its Community Education Initiative, Apple says that its work with 4-H programs has reached over 90,000 young people from communities across the US that are traditionally underrepresented in technology.Mark Light has introduced thousands of young pe…',
#    'url': 'https://appleinsider.com/articles/24/08/21/apple-spotlights-how-its-technology-is-helping-4-h-youth-development',
#    'urlToImage': 'https://photos5.appleinsider.com/gallery/60768-125080-000-lede-teaching-xl.jpg',
#    'publishedAt': '2024-08-21T13:33:52Z',
#    'content': 'Mark Light has introduced thousands of young people to Apple technology through bus events in rural, suburban, and urban communities across Ohio. (Source: Apple)\r\nAs part of its Community Education I… [+2011 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Geoff Weiss',
#    'title': 'Pumpkin Spice Latte season is coming earlier than ever. Starbucks could use the jolt.',
#    'description': "The PSL debuted in early September back in 2015, though its release has come earlier and earlier. Now it's back on Thursday.",
#    'url': 'https://www.businessinsider.com/starbucks-pumpkin-spice-latte-season-begins-early-2024-8',
#    'urlToImage': 'https://i.insider.com/66c5fc4e1aa2ac29ee32d872?width=1200&format=jpeg',
#    'publishedAt': '2024-08-21T15:53:40Z',
#    'content': "Starbucks' fall menu marks the unofficial start of the season, it said.Starbucks\r\n<ul><li>Pumpkin Spice Lattes are again arriving in the dead of summer.</li><li>There was a time the drink actually la… [+1467 chars]"},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Ben Lovejoy',
#    'title': 'Apple Music free trial back to three months if you sign up now',
#    'description': 'Those who’ve never tried the service can now get an Apple Music free trial for three months, rather than just one.\n\n\n\nThis is the same deal the company offered when it first launched the streaming music service, but it later reduced it to one month … \n\n\n\n mor…',
#    'url': 'https://9to5mac.com/2024/08/20/apple-music-free-trial-three-months/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/08/Apple-Music-free-trial-back-to-three-months.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-20T11:24:47Z',
#    'content': 'Those who’ve never tried the service can now get an Apple Music free trial for three months, rather than just one.\r\nThis is the same deal the company offered when it first launched the streaming musi… [+1620 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Ryan Christoffel',
#    'title': 'Gurman: iOS 18 is ‘final’ with beta 7 until iPhone 16 launch',
#    'description': 'Today Apple released iOS 18 beta 7 to developers. Historically, there would be a beta 8 during the last week of August. However, according to a new X post by Mark Gurman, that’s being called into question.\n\n\n\n more…',
#    'url': 'https://9to5mac.com/2024/08/20/gurman-ios-18-beta-7-is-feature-complete-until-iphone-16-launch/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/08/ios-18-generic-bg.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-20T17:54:30Z',
#    'content': 'Today Apple released iOS 18 beta 7 to developers. Historically, there would be a beta 8 during the last week of August. However, according to a new X post by Mark Gurman, thats being called into ques… [+1371 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Ryan Christoffel',
#    'title': 'Apple releases beta 7 for macOS Sequoia, visionOS 2, and more',
#    'description': 'Apple has a variety of new beta releases available now. Developer beta 7 is rolling out for macOS Sequoia, iPadOS 18, visionOS 2, watchOS 11, and tvOS 18. These join the beta 7 debut for iOS 18.\n\n\n\n more…',
#    'url': 'https://9to5mac.com/2024/08/20/apple-releases-beta-7-for-macos-sequoia-visionos-2-more/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/07/apple-device-lineup.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-20T17:13:12Z',
#    'content': 'Apple has a variety of new beta releases available now. Developer beta 7 is rolling out for macOS Sequoia, iPadOS 18, visionOS 2, watchOS 11, and tvOS 18. These join the beta 7 debut for iOS 18.\r\nWe … [+1621 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Ben Lovejoy',
#    'title': 'UK antitrust investigation into Apple closed for now – but will likely re-open',
#    'description': 'A UK antitrust investigation into Apple has officially closed – despite finding the company to be at fault – after the regulator missed a legal deadline.\n\n\n\nHowever, a case seems almost certain to be re-opened under an upcoming law which will grant new powers…',
#    'url': 'https://9to5mac.com/2024/08/21/uk-antitrust-investigation-into-apple-closed/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/08/UK-antitrust-investigation-into-Apple-closed.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-21T12:11:39Z',
#    'content': 'A UK antitrust investigation into Apple has officially closed despite finding the company to be at fault after the regulator missed a legal deadline.\r\nHowever, a case seems almost certain to be re-op… [+1760 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Ben Lovejoy',
#    'title': 'Apple and 4-H program brings tech to kids, not just agriculture',
#    'description': 'Apple and 4-H are working together to extend the training offered by the youth development network, which is best known for an agricultural focus.\n\n\n\nWith Apple’s support, the network of youth organizations is teaching kids to program in Swift, as well as use…',
#    'url': 'https://9to5mac.com/2024/08/21/apple-and-4-h/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/08/Apple-and-4-H.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-21T13:37:55Z',
#    'content': 'Apple and 4-H are working together to extend the training offered by the youth development network, which is best known for an agricultural focus.\r\nWith Apple’s support, the network of youth organiza… [+2409 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Seth Kurkowski',
#    'title': '9to5Mac Daily: August 20, 2024 – Apple Podcasts on the web, more',
#    'description': 'Listen to a recap of the top stories of the day from\xa09to5Mac. 9to5Mac Daily is available\xa0on iTunes and Apple’s Podcasts app,\xa0Stitcher,\xa0TuneIn,\xa0Google Play, or through our\xa0dedicated RSS feed\xa0for Overcast and other podcast players.\n\n\n\nSponsored by 9to5Mac Daily…',
#    'url': 'https://9to5mac.com/2024/08/20/daily-august-20-2024/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2021/12/9to5Mac-Daily-art-lead.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-20T15:47:00Z',
#    'content': 'Listen to a recap of the top stories of the day from\xa09to5Mac. 9to5Mac Daily is available\xa0on iTunes and Apples Podcasts app,\xa0Stitcher,\xa0TuneIn,\xa0Google Play, or through our\xa0dedicated RSS feed\xa0for Overca… [+848 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Ben Lovejoy',
#    'title': 'iPhone 16 launch will see Apple hit major milestone in reducing dependence on China',
#    'description': 'Apple will this year hit a major milestone in its efforts to reduce its manufacturing dependence on China, according to a new report today.\n\n\n\nWhen the iPhone 16 line-up launches, both Pro models will be made in India within weeks of launch, something the com…',
#    'url': 'https://9to5mac.com/2024/08/20/iphone-16-launch-major-milestone/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/08/Apple-to-hit-major-milestone-in-reducing-dependence-on-China-with-iPhone-16-launch.webp?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-20T11:00:31Z',
#    'content': 'Apple will this year hit a major milestone in its efforts to reduce its manufacturing dependence on China, according to a new report today.\r\nWhen the iPhone 16 line-up launches, both Pro models will … [+2056 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Seth Kurkowski',
#    'title': '9to5Mac Daily: August 21, 2024 – macOS Sequoia features, Apple Watch Series 10 rumors',
#    'description': 'Listen to a recap of the top stories of the day from\xa09to5Mac. 9to5Mac Daily is available\xa0on iTunes and Apple’s Podcasts app,\xa0Stitcher,\xa0TuneIn,\xa0Google Play, or through our\xa0dedicated RSS feed\xa0for Overcast and other podcast players.\n\n\n\nSponsored by 9to5Mac Daily…',
#    'url': 'https://9to5mac.com/2024/08/21/daily-august-21-2024/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2021/12/9to5Mac-Daily-art-lead.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-21T17:49:42Z',
#    'content': 'Listen to a recap of the top stories of the day from\xa09to5Mac. 9to5Mac Daily is available\xa0on iTunes and Apples Podcasts app,\xa0Stitcher,\xa0TuneIn,\xa0Google Play, or through our\xa0dedicated RSS feed\xa0for Overca… [+848 chars]'},
#   {'source': {'id': None, 'name': 'Android Authority'},
#    'author': 'Kaitlyn Cimino',
#    'title': 'Apple Ring wishlist: All the features I want to see',
#    'description': 'The smart ring arena is heating up. Find out everything I would love to see Apple bring to the scene with a potential Apple Ring.',
#    'url': 'https://www.androidauthority.com/apple-ring-3464532/',
#    'urlToImage': 'https://www.androidauthority.com/wp-content/uploads/2024/08/Smart-Rings-Apple-Logo-scaled.jpg',
#    'publishedAt': '2024-08-22T00:01:20Z',
#    'content': 'As smart ring competitions continues to expand, there is still one name seemingly MIA: Apple has yet to join the fray. Weve seen a handful of rumors and suggestions that the company has considered ma… [+5236 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Justin Kahn',
#    'title': 'Deals: Apple Watch Ultra 2 $100 off, M4 iPad Pro $200 off, M2 iPad Air, Magic Keyboards $99 off, more',
#    'description': 'Today’s 9to5Toys Lunch Break is now ready to go with notable deals on Apple Watch Ultra 2, both of the new iPads, Magic keyboards, charging gear, and more. Apple Watch Ultra 2 has returned to Prime Day pricing with all band options now marked down by $100. Mo…',
#    'url': 'https://9to5mac.com/2024/08/20/deals-apple-watch-ultra-2-ipad-pro-magic-keyboards/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/08/Apple-deals-M4-iPAd-Pro-iPad-Air-apple-Watch-Ultra.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-20T15:46:16Z',
#    'content': 'Today’s 9to5Toys Lunch Break is now ready to go with notable deals on Apple Watch Ultra 2, both of the new iPads, Magic keyboards, charging gear, and more. Apple Watch Ultra 2 has returned to Prime D… [+7341 chars]'},
#   {'source': {'id': None, 'name': 'AppleInsider'},
#    'author': 'news@appleinsider.com (Malcolm Owen)',
#    'title': 'How new Apple Music subscribers can get three months for free',
#    'description': "New users can now try out Apple Music for three months for free, instead of the normal one month trial. Here's how to get the super-sized music streaming introductory offer.Apple MusicApple offers people who haven't tried Apple Music before a free month's tri…",
#    'url': 'https://appleinsider.com/articles/24/08/20/how-new-apple-music-subscribers-can-get-three-months-for-free',
#    'urlToImage': 'https://photos5.appleinsider.com/gallery/60748-125056-59342-121119-amplaylists-xl-xl.jpg',
#    'publishedAt': '2024-08-20T13:51:54Z',
#    'content': "Apple Music\r\nNew users can now try out Apple Music for three months for free, instead of the normal one month trial. Here's how to get the super-sized music streaming introductory offer. \r\nApple offe… [+1321 chars]"},
#   {'source': {'id': None, 'name': 'Android Central'},
#    'author': 'bradypsnyder@gmail.com (Brady Snyder)',
#    'title': 'A year later, Pixel 8 Pro users can officially use Zoom Enhance — with lessons learned',
#    'description': 'It took Google nearly a year to ship Zoom Enhance, and it couldn’t do so before announcing the Pixel 8 Pro’s successor.',
#    'url': 'https://www.androidcentral.com/apps-software/lesson-learned-with-google-zoom-enhance-feature',
#    'urlToImage': 'https://cdn.mos.cms.futurecdn.net/AriHAnbWjHYfa6q4QWWvVG-1200-80.jpg',
#    'publishedAt': '2024-08-21T16:31:10Z',
# ...
#    'urlToImage': 'https://photos5.appleinsider.com/gallery/60712-125032-60616-124774-headerip16-xl-xl.jpg',
#    'publishedAt': '2024-08-20T11:02:45Z',
#    'content': "Apple's iPhone 16 range is set to usher in a series of meaningful hardware improvements and features\r\nApple's iPhone 16 is less than a month away. Here's what's actually known about the upcoming mode… [+11651 chars]"},
#   {'source': {'id': None, 'name': 'AppleInsider'},
#    'author': 'news@appleinsider.com (Amber Neely)',
#    'title': 'Customers can now extend AppleCare+ up to 45 days after it expires',
#    'description': 'Apple has recently increased the number of days a customer can extend their AppleCare+ coverage to 45 days, up from the previous 30.AppleCare+ plans can now be extended up to 45 days after they expire in Australia, Austria, Canada, Denmark, Finland, France, G…',
#    'url': 'https://appleinsider.com/articles/24/08/20/customers-can-now-extend-applecare-up-to-45-days-after-it-expires',
#    'urlToImage': 'https://photos5.appleinsider.com/gallery/50275-98761-000-lead-AppleCare+-xl.jpg',
#    'publishedAt': '2024-08-20T20:59:11Z',
#    'content': 'Apple has recently increased the number of days a customer can extend their AppleCare+ coverage to 45 days, up from the previous 30.\r\nAppleCare+ plans can now be extended up to 45 days after they exp… [+662 chars]'},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Aashna Gheewalla',
#    'title': "Save 55% Off a Pair of Beats Solo 3 Headphones Before It's Too Late",
#    'description': 'These Beats Solo 3 headphones are $200 off for a limited time only.',
#    'url': 'https://www.cnet.com/deals/save-55-off-a-pair-of-beats-solo-3-headphones-before-its-too-late/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/15ceb1b129d29a2167eee9bb8d725fec96acf3b5/hub/2024/08/21/d1d2e08c-f2bc-45a8-a83c-96cca68cf4f9/beats-solo-3-wireless-headphones-in-rose-gold.jpg?auto=webp&fit=crop&height=675&width=1200',
#    'publishedAt': '2024-08-21T12:32:00Z',
#    'content': "Beats headphones often find themselves on our list of CNET's favorite\xa0headphones\xa0thanks to a combination of a popular sound signature and great aesthetics. They're often prohibitively expensive thoug… [+940 chars]"},
#   {'source': {'id': None, 'name': 'AppleInsider'},
#    'author': 'news@appleinsider.com (Christine McKee)',
#    'title': "Apple's M3 Pro 14-inch MacBook Pro drops to $1,499, the lowest price ever",
#    'description': 'A record-breaking MacBook Pro 14-inch price drop is knocking a staggering $500 off the M3 Pro model at Amazon, Best Buy and B&H. Grab the deal while supplies last.Save $500 on this 14-inch MacBook Pro.To snap up the deal while supplies last, head over to B&H …',
#    'url': 'https://appleinsider.com/articles/24/08/20/apples-m3-pro-14-inch-macbook-pro-drops-to-1499-the-lowest-price-ever',
#    'urlToImage': 'https://photos5.appleinsider.com/gallery/60757-125067-14-inch-macbook-pro-m3-pro-1499-copy-xl.jpg',
#    'publishedAt': '2024-08-20T20:57:29Z',
#    'content': 'Save $500 on this 14-inch MacBook Pro.\r\nA record-breaking MacBook Pro 14-inch price drop is knocking a staggering $500 off the M3 Pro model at Amazon, Best Buy and B&amp;H. Grab the deal while suppli… [+1152 chars]'},
#   {'source': {'id': None, 'name': 'AppleInsider'},
#    'author': 'news@appleinsider.com (Malcolm Owen)',
#    'title': "Latest iOS 18 beta is 'final' for all but the iPhone 16 models",
#    'description': "The seventh developer beta of iOS 18 may be the same build that iPhone owners will upgrade to, as it is apparently finalized for features for current-generation models.A render of the iPhone 16Apple's lengthy list of features and changes it is bringing to the…",
#    'url': 'https://appleinsider.com/articles/24/08/20/latest-ios-18-beta-is-final-for-all-but-the-iphone-16-models',
#    'urlToImage': 'https://photos5.appleinsider.com/gallery/60755-125065-iphone-16-ios-xl.jpg',
#    'publishedAt': '2024-08-20T18:50:43Z',
#    'content': 'A render of the iPhone 16\r\nLast updated 10 minutes ago\r\nThe seventh developer beta of iOS 18 may be the same build that iPhone owners will upgrade to, as it is apparently finalized for features for c… [+1492 chars]'},
#   {'source': {'id': None, 'name': 'Phandroid - News for Android'},
#    'author': 'Tyler Lee',
#    'title': 'iPhone 16 launch date leaked!',
#    'description': 'According to the latest rumors, here is when we can expect Apple to officially launch the iPhone 16 series next month.\nThe post iPhone 16 launch date leaked! appeared first on Phandroid.',
#    'url': 'https://phandroid.com/2024/08/20/iphone-16-launch-date-leaked/',
#    'urlToImage': 'https://phandroid.com/wp-content/uploads/2023/12/iPhone-12-Pro-Colors.jpg',
#    'publishedAt': '2024-08-20T10:17:30Z',
#    'content': 'The iPhone 16 launch is coming soon. When? We dont know for sure. However, a post on X by Majin Bu claims that according to their sources, the iPhone 16 will be officially announced on the 10th of Se… [+1179 chars]'},
#   {'source': {'id': None, 'name': 'Phandroid - News for Android'},
#    'author': 'Tyler Lee',
#    'title': 'Apple’s foldable plans have been delayed…yet again!',
#    'description': 'Apple was rumored to launch a new foldable device in the coming years, but now a new report suggests it could be delayed further.\nThe post Apple’s foldable plans have been delayed…yet again! appeared first on Phandroid.',
#    'url': 'https://phandroid.com/2024/08/22/apples-foldable-plans-have-been-delayed-yet-again/',
#    'urlToImage': 'https://phandroid.com/wp-content/uploads/2021/06/iPad-Pro-2021-with-Android-Figures.jpg',
#    'publishedAt': '2024-08-22T11:14:12Z',
#    'content': 'Ever since Samsung burst onto the scene with their foldables, many have been wondering if Apple will follow suit. There have been rumors that Apple is working on a foldable device, where past rumors … [+1313 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Ryan Christoffel',
#    'title': 'iPhone 17 Air won’t be the best iPhone, but it will be the future',
#    'description': 'Apple’s iPhone 17 lineup will be weird. We’re just weeks away from the iPhone 16 launch, but it’s 2025’s models at the center of lots of rumors. Specifically, the ultra-slim ‘Air’ model stands to shake up the iPhone 17 lineup. Here’s why next year’s innovativ…',
#    'url': 'https://9to5mac.com/2024/08/20/iphone-17-air-wont-be-the-best-iphone-but-it-will-be-the-future/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/08/iphone-17-air.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2024-08-20T20:43:42Z',
#    'content': 'Apples iPhone 17 lineup will be weird. Were just weeks away from the iPhone 16 launch, but its 2025s models at the center of lots of rumors. Specifically, the ultra-slim Air model stands to shake up … [+3437 chars]'},
#   {'source': {'id': None, 'name': 'Small Business Trends'},
#    'author': 'Joshua Sophy',
#    'title': 'Apple Announces New NFC In-App Transaction Capabilities for Developers Starting with iOS 18.1',
#    'description': 'Apple says developers have new NFC in-app transaction capabilities with the release of a new system update.',
#    'url': 'https://smallbiztrends.com/apple-developers-nfc-in-app-transactions/',
#    'urlToImage': 'https://smallbiztrends.com/wp-content/themes/sahifa/images/logo-full.jpg',
#    'publishedAt': '2024-08-20T15:43:21Z',
#    'content': 'Apple has announced that starting with the upcoming iOS 18.1 release, developers will be able to offer NFC contactless transactions directly within their own apps using the Secure Element (SE), separ… [+2097 chars]'},
#   {'source': {'id': None, 'name': 'iMore'},
#    'author': 'alexblake.imore@gmail.com (Alex Blake)',
#    'title': 'Control Center has been supercharged in iOS 18 — here’s how to get the most from it',
#    'description': "In iOS 18, Apple has updated Control Center with new tools and features. Here's how to use them all.",
#    'url': 'https://www.imore.com/ios/control-center-has-been-supercharged-in-ios-18-heres-how-to-get-the-most-from-it',
#    'urlToImage': 'https://cdn.mos.cms.futurecdn.net/K3B2shCVUowLKwrH64jRXR-1200-80.jpg',
#    'publishedAt': '2024-08-20T10:12:27Z',
#    'content': 'The iOS 18 update has brought a lot of changes to all the best iPhones, and one of the most interesting – and wide-ranging – is what’s happened to Control Center. Apple’s quick-access dashboard has h… [+6108 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Juli Clover',
#    'title': 'App Store VP Departs As Apple Prepares for Organizational Changes',
#    'description': 'App Store vice president Matt Fischer is set to leave the company as Apple prepares for an \u200cApp Store\u200c reorganization to deal with regulatory changes, reports Bloomberg.\n\n\n\n\n\nApple plans to split its \u200cApp Store\u200c group into two teams, one that handles the \u200cApp…',
#    'url': 'https://www.macrumors.com/2024/08/21/app-store-organizational-changes/',
#    'urlToImage': 'https://images.macrumors.com/t/Z4nU2dRocDnr4NPvf-sGNedmPGA=/2250x/article-new/2022/01/iOS-App-Store-General-Feature-JoeBlue.jpg',
#    'publishedAt': '2024-08-21T20:11:59Z',
#    'content': 'App Store vice president Matt Fischer is set to leave the company as Apple prepares for an \u200cApp Store\u200c reorganization to deal with regulatory changes, reports Bloomberg.\r\nApple plans to split its \u200cAp… [+1029 chars]'},
#   {'source': {'id': None, 'name': 'Yanko Design'},
#    'author': 'Sarang Sheth',
#    'title': 'The MERAKI Espresso Machine is what you get if Apple and Dyson collaborated to design a coffee maker',
#    'description': 'The MERAKI Espresso Machine is what you get if Apple and Dyson collaborated to design a coffee makerA clean design, flawless and silent operation, and perfect results with just the right amount of tech. That’s what the Meraki promises, as compared to...',
#    'url': 'https://www.yankodesign.com/2024/08/20/the-meraki-espresso-machine-is-what-you-get-if-apple-and-dyson-collaborated-to-design-a-coffee-maker/',
#    'urlToImage': 'https://www.yankodesign.com/images/design_news/2024/08/the-meraki-espresso-machine-is-what-you-get-if-apple-and-dyson-collaborated-to-design-a-coffee-maker/Meraki_Ultimate_Espresso_Machine_hero.jpg',
#    'publishedAt': '2024-08-21T01:45:23Z',
#    'content': 'A clean design, flawless and silent operation, and perfect results with just the right amount of tech. That’s what the Meraki promises, as compared to other espresso machines which can be cumbersome,… [+7038 chars]'},
#   {'source': {'id': None, 'name': 'Android Authority'},
#    'author': 'Ryan Haines',
#    'title': 'The Google Pixel 9 Pro XL is my favorite iPhone ever',
#    'description': "Put away your pitchforks, I don't want a Pixel 9 Pro XL that runs iOS. Instead, I think Google finally made a flagship to tempt Apple users.",
#    'url': 'https://www.androidauthority.com/google-pixel-9-pro-xl-iphone-3473381/',
#    'urlToImage': 'https://www.androidauthority.com/wp-content/uploads/2024/08/Google-Pixel-9-Pro-XL-rear-hero.jpg',
#    'publishedAt': '2024-08-21T17:00:32Z',
#    'content': 'Now that Pixel and iPhone fans are mad at me, Ill say it again. The Pixel 9 Pro XL is by far the best iPhone ever made. Yes, that means it looks and feels more like an iPhone than ever, but Im not su… [+10406 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Juli Clover',
#    'title': 'Apple Seeds Seventh Beta of tvOS 18 to Developers',
#    'description': 'Apple today seeded the seventh beta of the upcoming tvOS 18 refresh to developers for testing purposes, with the beta coming a week after the sixth beta came out.\n\n\n\n\n\nRegistered developers are able to download the tvOS 18 update by opting in to the beta thro…',
#    'url': 'https://www.macrumors.com/2024/08/20/apple-seeds-tvos-18-beta-7/',
#    'urlToImage': 'https://images.macrumors.com/t/GAyquGnnVSnhxBeZ-t47PVsJQ04=/2500x/article-new/2024/06/apple-tv-4k-new-orange.jpg',
#    'publishedAt': '2024-08-20T17:02:00Z',
#    'content': 'Apple today seeded the seventh beta of the upcoming tvOS 18 refresh to developers for testing purposes, with the beta coming a week after the sixth beta came out.\r\nRegistered developers are able to d… [+947 chars]'},
#   {'source': {'id': None, 'name': 'Techdirt'},
#    'author': 'Gretchen Heckmann',
#    'title': 'Daily Deal: 2-in-1 Keychain Wireless Charger for iPhone and Apple Watch',
#    'description': 'This 2-in-1 Keychain Wireless Charger with 2,500mAh battery will charge your Apple Watch 3-5 times on a full charge. Its magnetic design ensures perfect alignment and it works seamlessly with all Apple Watch series. It features Type-C port for versatile charg…',
#    'url': 'https://www.techdirt.com/2024/08/21/daily-deal-2-in-1-keychain-wireless-charger-for-iphone-and-apple-watch-2/',
#    'urlToImage': 'https://www.techdirt.com/wp-content/themes/techdirt/assets/images/td-rect-logo-white.png',
#    'publishedAt': '2024-08-21T17:53:45Z',
#    'content': 'from the good-deals-on-cool-stuff dept\r\nThis 2-in-1 Keychain Wireless Charger with 2,500mAh battery will charge your Apple Watch 3-5 times on a full charge. Its magnetic design ensures perfect alignm… [+389 chars]'},
#   {'source': {'id': None, 'name': 'GSMArena.com'},
#    'author': 'Michail',
#    'title': 'Kuo: Apple foldable delayed, again',
#    'description': 'Foldable phones have been developing rapidly in the last five years and some manufacturers are even experimenting with larger form factors like laptops while others like Apple have yet to dip their toes in the foldable market. There’s no shortage of rumors cl…',
#    'url': 'https://www.gsmarena.com/kuo_apple_foldable_delayed_again-news-64235.php',
#    'urlToImage': 'https://fdn.gsmarena.com/imgroot/news/24/08/apple-foldable-delayed-yet-again/-952x498w6/gsmarena_00.jpg',
#    'publishedAt': '2024-08-22T10:33:01Z',
#    'content': 'Foldable phones have been developing rapidly in the last five years and some manufacturers are even experimenting with larger form factors like laptops while others like Apple have yet to dip their t… [+997 chars]'},
#   {'source': {'id': None, 'name': 'AppleInsider'},
#    'author': 'news@appleinsider.com (William Gallagher)',
#    'title': 'Photomator and Pixelmator Pro add custom auto-straightening',
#    'description': "Claiming a five-fold improvement in accuracy, image editing developer Pixelmator has replaced Apple's straightening tool with its own for both Pixelmator Pro and Photomator.Photomator works across Mac, iPad, iPhone, and Apple Vision ProPixelmator Pro for the …",
#    'url': 'https://appleinsider.com/articles/24/08/20/photomator-and-pixelmator-pro-add-custom-auto-straightening',
#    'urlToImage': 'https://photos5.appleinsider.com/gallery/60729-125017-000-lede-Photomator-xl.jpg',
#    'publishedAt': '2024-08-20T13:06:09Z',
#    'content': "Photomator works across Mac, iPad, iPhone, and Apple Vision Pro\r\nClaiming a five-fold improvement in accuracy, image editing developer Pixelmator has replaced Apple's straightening tool with its own … [+1285 chars]"},
#   {'source': {'id': None, 'name': 'AppleInsider'},
#    'author': 'news@appleinsider.com (Andrew Orr)',
#    'title': "iPhone character entry glitch crashes search, but it's not a bad bug",
#    'description': 'A recently discovered bug in iOS and iPadOS has been causing brief and mostly inconsequential crashes when a sequence of characters is typed into specific search fields.A small bug is affecting iOS searchOn August 21, 2024, a security researcher reported that…',
#    'url': 'https://appleinsider.com/articles/24/08/21/iphone-character-entry-glitch-crashes-search-but-its-not-a-bad-bug',
#    'urlToImage': 'https://photos5.appleinsider.com/gallery/60772-125094-bug-xl.jpg',
#    'publishedAt': '2024-08-21T19:39:13Z',
#    'content': 'A small bug is affecting iOS search\r\nA recently discovered bug in iOS and iPadOS has been causing brief and mostly inconsequential crashes when a sequence of characters is typed into specific search … [+1261 chars]'}]}

# %%
write(data_raw)
# Out:
# tomastestproject-433206.testdb_1.test_3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[219], line 1
# ----> 1 write(data_raw)
#
# Cell In[216], line 14, in write(data, table, project_id, dataset)
#       9 print(table_id)
#      10 #data_to_insert = json.dumps(data['articles'])
#      11 # rows_to_insert = {'data': data['articles']}
# ---> 14 errors = client.insert_rows_json(table_id, data)
#      15 print(errors)
#
# File ~/Desktop/Skola/test_project/testv/lib/python3.12/site-packages/google/cloud/bigquery/client.py:3832, in Client.insert_rows_json(self, table, json_rows, row_ids, skip_invalid_rows, ignore_unknown_values, template_suffix, retry, timeout)
#    3764 """Insert rows into a table without applying local type conversions.
#    3765
#    3766 See
#    (...)
#    3827     TypeError: if `json_rows` is not a `Sequence`.
#    3828 """
#    3829 if not isinstance(
#    3830     json_rows, (collections_abc.Sequence, collections_abc.Iterator)
#    3831 ):
# -> 3832     raise TypeError("json_rows argument should be a sequence of dicts")
#    3833 # Convert table to just a reference because unlike insert_rows,
#    3834 # insert_rows_json doesn't need the table schema. It's not doing any
#    3835 # type conversions.
#    3836 table = _table_arg_to_table_ref(table, default_project=self.project)
#
# TypeError: json_rows argument should be a sequence of dicts
